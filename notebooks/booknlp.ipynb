# %%
# %pip install booknlp --quiet
# Out:
#      |████████████████████████████████| 2.4 MB 8.8 MB/s
#      |████████████████████████████████| 5.5 MB 11.2 MB/s
#      |████████████████████████████████| 182 kB 16.9 MB/s
#      |████████████████████████████████| 7.6 MB 45.3 MB/s
#   Building wheel for booknlp (setup.py) ... done

# %%
from booknlp.booknlp import BookNLP
import pandas as pd
from pprint import pprint

# %%
model_params={
		"pipeline":"entity,quote,supersense,event,coref", 
		"model":"big"
	}

booknlp=BookNLP("en", model_params)
# Out:
# {'pipeline': 'entity,quote,supersense,event,coref', 'model': 'big'}
# downloading entities_google_bert_uncased_L-6_H-768_A-12-v1.0.model
# downloading coref_google_bert_uncased_L-12_H-768_A-12-v1.0.model
# downloading speaker_google_bert_uncased_L-12_H-768_A-12-v1.0.1.model
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/384 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/270M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/385 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# --- startup: 43.272 seconds ---

# %%
input_file="crime_and_punishment.txt"
output_directory="crime_and_punishment"
book_id="crime_and_punishment"

booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 38.515 seconds ---
# --- entities: 894.837 seconds ---
# --- quotes: 0.591 seconds ---
# Cannot resolve quotation
# --- attribution: 2130.899 seconds ---
# --- name coref: 0.782 seconds ---
# --- coref: 1183.279 seconds ---
# --- TOTAL (excl. startup): 4251.203 seconds ---, 256401 words

# %%
import sys
import csv
# wide future warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

csv.field_size_limit(sys.maxsize)
# Out:
# 9223372036854775807

# %%
# read json file
import json
with open('crime_and_punishment/crime_and_punishment.book') as f:
    data = json.load(f)

len(data["characters"])
# Out:
# 1474

# %%
data["characters"][0].keys()
# Out:
# dict_keys(['agent', 'patient', 'mod', 'poss', 'id', 'g', 'count', 'mentions'])

# %%
tokens = pd.read_csv("crime_and_punishment/crime_and_punishment.tokens", delimiter="\t", engine="python", encoding='utf-8', error_bad_lines=False)
tokens.head()
# Out:
# Skipping line 130152: unexpected end of data
#    paragraph_ID  sentence_ID  token_ID_within_sentence  \
# 0             0            0                         0
# 1             0            0                         1
# 2             0            0                         2
# 3             0            0                         3
# 4             0            0                         4
#
#    token_ID_within_document       word      lemma  byte_onset  byte_offset  \
# 0                         0       ﻿The       ﻿the           0            4
# 1                         1    Project    Project           5           12
# 2                         2  Gutenberg  Gutenberg          13           22
# 3                         3      eBook      eBook          23           28
# 4                         4         of         of          29           31
#
#   POS_tag fine_POS_tag dependency_relation  syntactic_head_ID event
# 0    PRON           DT                nmod                  3     O
# 1   PROPN          NNP            compound                  3     O
# 2   PROPN          NNP            compound                  3     O
# 3   PROPN          NNP               nsubj                 14     O
# 4     ADP           IN                prep                  3     O

# %%
entities = pd.read_csv("crime_and_punishment/crime_and_punishment.entities", delimiter="\t")
entities.head()
# Out:
#    COREF  start_token  end_token  prop  cat                           text
# 0    111           10         11  PROP  PER              Fyodor Dostoevsky
# 1      1           22         24  PROP  LOC              the United States
# 2    355           26         31   NOM  LOC  most other parts of the world
# 3    356           30         31   NOM  LOC                      the world
# 4    357           42         42  PRON  PER                            You

# %%
quote = pd.read_csv("crime_and_punishment/crime_and_punishment.quotes", delimiter="\t")
quote.head()
# Out:
#    quote_start  quote_end mention_start mention_end mention_phrase char_id  \
# 0          283        287           275         275             he     111
# 1          374        405           408         408             I.     121
# 2          411        417           422         422            him     111
# 3          466        580           463         463     Dostoevsky     111
# 4          704        708           663         663             He     111
#
#                                                quote
# 0                                    “ Poor Folk . ”
# 1  “ taking part in conversations against the cen...
# 2                           “ stern and just man , ”
# 3  “ They snapped words over our heads , and they...
# 4                                   “ Dead House , ”

# %%
supsense = pd.read_csv("crime_and_punishment/crime_and_punishment.supersense", delimiter="\t")
supsense.head()
# Out:
#    start_token  end_token supersense_category               text
# 0            2          2  noun.communication          Gutenberg
# 1            7          7            noun.act         Punishment
# 2           10         11         noun.person  Fyodor Dostoevsky
# 3           14         14        verb.stative                 is
# 4           17         17            noun.act                use

# %% [markdown]
# ## Analyze characters
#
# Code source: https://booknlp.pythonhumanities.com/04_character_analysis.html

# %%
import json
from collections import Counter

def proc(filename):
    with open(filename) as file:
        data=json.load(file)
    return data

def get_counter_from_dependency_list(dep_list):
    counter=Counter()
    for token in dep_list:
        term=token["w"]
        tokenGlobalIndex=token["i"]
        counter[term]+=1
    return counter


def create_character_data(data, printTop):
    character_data = {}
    for character in data["characters"]:

        agentList=character["agent"]
        patientList=character["patient"]
        possList=character["poss"]
        modList=character["mod"]

        character_id=character["id"]
        count=character["count"]

        referential_gender_distribution=referential_gender_prediction="unknown"

        if character["g"] is not None and character["g"] != "unknown":
            referential_gender_distribution=character["g"]["inference"]
            referential_gender=character["g"]["argmax"]

        mentions=character["mentions"]
        proper_mentions=mentions["proper"]
        max_proper_mention=""
        
        #Let's create some empty lists that we can append to.
        poss_items = []
        agent_items = []
        patient_items = []
        mod_items = []
    
        # just print out information about named characters
        if len(mentions["proper"]) > 0:
            max_proper_mention=mentions["proper"][0]["n"]
            for k, v in get_counter_from_dependency_list(possList).most_common(printTop):
                poss_items.append((v,k))
                
            for k, v in get_counter_from_dependency_list(agentList).most_common(printTop):
                agent_items.append((v,k))     

            for k, v in get_counter_from_dependency_list(patientList).most_common(printTop):
                patient_items.append((v,k))     

            for k, v in get_counter_from_dependency_list(modList).most_common(printTop):
                mod_items.append((v,k))  

            
            
            
            # print(character_id, count, max_proper_mention, referential_gender)
            character_data[character_id] = {"id": character_id,
                                  "count": count,
                                  "max_proper_mention": max_proper_mention,
                                  "referential_gender": referential_gender,
                                  "possList": poss_items,
                                  "agentList": agent_items,
                                  "patientList": patient_items,
                                  "modList": mod_items
                                 }
                                
    return character_data


def find_verb_usage(character_data, analysis=["agent", "patient"]):
    new_analysis = []
    for item in analysis:
        if item == "agent":
            new_analysis.append("agentList")
        elif item == "patient":
            new_analysis.append("patientList")
    main_agents = {}
    main_patients = {}
    for character in character_data:
        temp_data = character_data[character]
        for item in new_analysis:
            for verb in temp_data[item]:
                verb = verb[1].lower()
                if item == "agentList":
                    if verb not in main_agents:
                        main_agents[verb] = [(character, temp_data["max_proper_mention"])]
                    else:
                        main_agents[verb].append((character, temp_data["max_proper_mention"]))
                elif item == "patientList":
                    if verb not in main_patients:
                        main_patients[verb] = [(character, temp_data["max_proper_mention"])]
                    else:
                        main_patients[verb].append((character, temp_data["max_proper_mention"]))
    verb_usage = {"agent": main_agents,
                 "patient": main_patients}
    return verb_usage

# %%
data=proc("crime_and_punishment/crime_and_punishment.book")

# %%
character_data = create_character_data(data, 20)

# %%
pprint(character_data)
# Out:
# {111: {'agentList': [(2, 'contrived'),
#                      (2, 'started'),
#                      (2, 'became'),
#                      (1, 'begun'),
#                      (1, 'says'),
#                      (1, 'concluded'),
#                      (1, 'had'),
#                      (1, 'thought'),
#                      (1, 'bid'),
#                      (1, 'recurs'),
#                      (1, 'describes'),
#                      (1, 'insists'),
#                      (1, 'began'),
#                      (1, 'shown'),
#                      (1, 'suffered'),
#                      (1, 'lost'),
#                      (1, 'took'),
#                      (1, 'made'),
#                      (1, 'received'),
#                      (1, 'died')],
#        'count': 72,
#        'id': 111,
#        'max_proper_mention': 'Dostoevsky',
#        'modList': [(1, 'son'), (1, 'writer')],
#        'patientList': [(1, 'found'),
#                        (1, 'arrested'),
#                        (1, 'accused'),
#                        (1, 'calls'),
#                        (1, 'condemned'),
#                        (1, 'led'),
#                        (1, 'allowed'),
#                        (1, 'weighed'),
#                        (1, 'forced'),
#                        (1, 'received'),
#                        (1, 'followed')],
#        'possList': [(5, 'brother'),
#                     (3, 'work'),
#                     (2, 'life'),
#                     (2, 'wife'),
#                     (1, 'parents'),
#                     (1, 'Majesty'),
#                     (1, 'mind'),
#                     (1, 'temper'),
#                     (1, 'case'),
#                     (1, 'writings'),
#                     (1, 'arrest'),
#                     (1, 'this'),
#                     (1, 'speech'),
#                     (1, 'insight'),
#                     (1, 'gifts')],
#        'referential_gender': 'he/him/his'},
#  112: {'agentList': [],
#        'count': 2,
#        'id': 112,
#        'max_proper_mention': 'Constance Garnett',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'she/her'},
#  116: {'agentList': [(1, 'published')],
#        'count': 2,
#        'id': 116,
#        'max_proper_mention': 'the poet Nekrassov',
#        'modList': [],
#        'patientList': [],
#        'possList': [(1, 'review')],
#        'referential_gender': 'he/him/his'},
#  120: {'agentList': [],
#        'count': 4,
#        'id': 120,
#        'max_proper_mention': 'Gogol',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  121: {'agentList': [],
#        'count': 2,
#        'id': 121,
#        'max_proper_mention': 'Nicholas',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  123: {'agentList': [],
#        'count': 2,
#        'id': 123,
#        'max_proper_mention': 'Mihail',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'they/them/their'},
#  126: {'agentList': [],
#        'count': 3,
#        'id': 126,
#        'max_proper_mention': 'Grigoryev',
#        'modList': [],
#        'patientList': [(1, 'untied')],
#        'possList': [(1, 'sanity')],
#        'referential_gender': 'he/him/his'},
#  128: {'agentList': [],
#        'count': 2,
#        'id': 128,
#        'max_proper_mention': 'Pushkin',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  131: {'agentList': [(77, 'said'),
#                      (73, 'know'),
#                      (57, 'felt'),
#                      (56, 'went'),
#                      (55, 'had'),
#                      (46, 'thought'),
#                      (45, 'looked'),
#                      (45, 'come'),
#                      (45, 'want'),
#                      (36, 'have'),
#                      (36, 'believe'),
#                      (36, 'walked'),
#                      (35, 'began'),
#                      (34, 'heard'),
#                      (31, 'think'),
#                      (29, 'tell'),
#                      (29, 'made'),
#                      (29, 'stood'),
#                      (28, 'turned'),
#                      (27, 'asked')],
#        'count': 4561,
#        'id': 131,
#        'max_proper_mention': 'Raskolnikov',
#        'modList': [(14, 'afraid'),
#                    (9, 'ill'),
#                    (8, 'man'),
#                    (7, 'able'),
#                    (6, 'asleep'),
#                    (6, 'sure'),
#                    (5, 'aware'),
#                    (5, 'delirious'),
#                    (4, 'glad'),
#                    (4, 'mistaken'),
#                    (4, 'ready'),
#                    (4, 'sick'),
#                    (4, 'tired'),
#                    (3, 'uneasy'),
#                    (3, 'pale'),
#                    (3, 'about'),
#                    (3, 'capable'),
#                    (3, 'weak'),
#                    (3, 'right'),
#                    (2, 'convinced')],
#        'patientList': [(16, 'tell'),
#                        (14, 'see'),
#                        (13, 'told'),
#                        (11, 'asked'),
#                        (7, 'cried'),
#                        (7, 'struck'),
#                        (7, 'left'),
#                        (7, 'arrest'),
#                        (6, 'take'),
#                        (6, 'thought'),
#                        (5, 'Excuse'),
#                        (5, 'betray'),
#                        (5, 'addressing'),
#                        (5, 'saw'),
#                        (5, 'put'),
#                        (4, 'taking'),
#                        (4, 'drew'),
#                        (4, 'know'),
#                        (4, 'Believe'),
#                        (4, 'assure')],
#        'possList': [(29, 'mind'),
#                     (27, 'hand'),
#                     (24, 'eyes'),
#                     (24, 'head'),
#                     (23, 'heart'),
#                     (22, 'mother'),
#                     (21, 'sister'),
#                     (18, 'hands'),
#                     (17, 'face'),
#                     (13, 'room'),
#                     (10, 'pocket'),
#                     (10, 'way'),
#                     (9, 'father'),
#                     (8, 'name'),
#                     (7, 'lips'),
#                     (7, 'life'),
#                     (7, 'article'),
#                     (6, 'back'),
#                     (6, 'strength'),
#                     (6, 'cap')],
#        'referential_gender': 'he/him/his'},
#  132: {'agentList': [(3, 'come'),
#                      (3, 'began'),
#                      (3, 'gave'),
#                      (2, 'knew'),
#                      (2, 'worked'),
#                      (2, 'did'),
#                      (2, 'get'),
#                      (2, 'lifted'),
#                      (2, 'used'),
#                      (1, 'standing'),
#                      (1, 'make'),
#                      (1, 'saying'),
#                      (1, 'said'),
#                      (1, 'pondering'),
#                      (1, 'undertook'),
#                      (1, 'employed'),
#                      (1, 'spoke'),
#                      (1, 'earned'),
#                      (1, 'dare'),
#                      (1, 'left')],
#        'count': 152,
#        'id': 132,
#        'max_proper_mention': 'Lizaveta',
#        'modList': [(2, 'hideous'),
#                    (1, 'woman'),
#                    (1, 'slave'),
#                    (1, 'fright'),
#                    (1, 'able'),
#                    (1, 'honest'),
#                    (1, 'submissive'),
#                    (1, 'timid'),
#                    (1, 'high'),
#                    (1, 'younger'),
#                    (1, 'sister'),
#                    (1, 'skinned'),
#                    (1, 'creature'),
#                    (1, 'simple'),
#                    (1, 'good'),
#                    (1, 'alive')],
#        'patientList': [(9, 'killed'),
#                        (3, 'know'),
#                        (2, 'murdered'),
#                        (1, 'beat'),
#                        (1, 'invited'),
#                        (1, 'had'),
#                        (1, 'send'),
#                        (1, 'stood'),
#                        (1, 'seen'),
#                        (1, 'brought'),
#                        (1, 'asked'),
#                        (1, 'murdering'),
#                        (1, 'kill'),
#                        (1, 'wear')],
#        'possList': [(8, 'sister'),
#                     (5, 'face'),
#                     (2, 'mind'),
#                     (2, 'hand'),
#                     (2, 'mouth'),
#                     (1, 'day'),
#                     (1, 'night'),
#                     (1, 'while'),
#                     (1, 'person'),
#                     (1, 'smile'),
#                     (1, 'queerness'),
#                     (1, 'money'),
#                     (1, 'finger'),
#                     (1, 'arms'),
#                     (1, 'bundle'),
#                     (1, 'cross')],
#        'referential_gender': 'she/her'},
#  133: {'agentList': [(1, 'went'),
#                      (1, 'keeps'),
#                      (1, 'give'),
#                      (1, 'gave'),
#                      (1, 'took'),
#                      (1, 'had'),
#                      (1, 'kept'),
#                      (1, 'know'),
#                      (1, 'killed')],
#        'count': 34,
#        'id': 133,
#        'max_proper_mention': 'Alyona Ivanovna',
#        'modList': [(1, 'sister'),
#                    (1, 'rate'),
#                    (1, 'rich'),
#                    (1, 'harpy'),
#                    (1, 'spiteful'),
#                    (1, 'uncertain')],
#        'patientList': [(1, 'give'),
#                        (1, 'bringing'),
#                        (1, 'brought'),
#                        (1, 'murdered')],
#        'possList': [(2, 'sister'), (1, 'address'), (1, 'name')],
#        'referential_gender': 'she/her'},
#  134: {'agentList': [(5, 'knows'),
#                      (4, 'grant'),
#                      (3, 'forgive'),
#                      (2, 'sent'),
#                      (2, 'give'),
#                      (2, 'delivered'),
#                      (2, 'allow'),
#                      (2, 'protect'),
#                      (2, 'broke'),
#                      (2, 'forbid'),
#                      (1, 'bless'),
#                      (1, 'have'),
#                      (1, 'going'),
#                      (1, 'get'),
#                      (1, 'tell'),
#                      (1, 'rest'),
#                      (1, 'cried'),
#                      (1, 'let'),
#                      (1, 'lets'),
#                      (1, 'do')],
#        'count': 101,
#        'id': 134,
#        'max_proper_mention': 'God',
#        'modList': [(2, 'merciful')],
#        'patientList': [(8, 'Thank'),
#                        (7, 'thank'),
#                        (1, 'excited--“good'),
#                        (1, 'see'),
#                        (1, 'found')],
#        'possList': [(2, 'sake'),
#                     (2, 'hands'),
#                     (1, 'excellency'),
#                     (1, 'hips'),
#                     (1, 'heels'),
#                     (1, 'means')],
#        'referential_gender': 'he/him/his'},
#  136: {'agentList': [(6, 'come'),
#                      (2, 'has'),
#                      (2, 'spoken'),
#                      (2, 'had'),
#                      (2, 'believed'),
#                      (1, 'went'),
#                      (1, 'struck'),
#                      (1, 'turned'),
#                      (1, 'understand'),
#                      (1, 'remained'),
#                      (1, 'regarded'),
#                      (1, 'decide'),
#                      (1, 'wanted'),
#                      (1, 'given'),
#                      (1, 'shown'),
#                      (1, 'understands'),
#                      (1, 'listened'),
#                      (1, 'make'),
#                      (1, 'suppose'),
#                      (1, 'declared')],
#        'count': 182,
#        'id': 136,
#        'max_proper_mention': 'Sofya Semyonovna',
#        'modList': [(1, 'name'),
#                    (1, 'character'),
#                    (1, 'orphan'),
#                    (1, 'thief'),
#                    (1, 'likely'),
#                    (1, 'horrified'),
#                    (1, 'bad'),
#                    (1, 'mother')],
#        'patientList': [(3, 'developing'),
#                        (3, 'see'),
#                        (2, 'tell'),
#                        (2, 'seen'),
#                        (1, 'addressing'),
#                        (1, 'respect'),
#                        (1, 'rouse'),
#                        (1, 'asked'),
#                        (1, 'wronged'),
#                        (1, 'attract'),
#                        (1, 'treated'),
#                        (1, 'despise'),
#                        (1, 'drove'),
#                        (1, 'gave'),
#                        (1, 'Protect'),
#                        (1, 'test'),
#                        (1, 'call'),
#                        (1, 'frighten'),
#                        (1, 'means'),
#                        (1, 'invited')],
#        'possList': [(6, 'pocket'),
#                     (2, 'sister'),
#                     (1, 'duty'),
#                     (1, 'action'),
#                     (1, 'protest'),
#                     (1, 'character'),
#                     (1, 'chastity'),
#                     (1, 'dignity'),
#                     (1, 'funeral'),
#                     (1, 'hand'),
#                     (1, 'part'),
#                     (1, 'finger'),
#                     (1, 'stepmother'),
#                     (1, 'ears'),
#                     (1, 'eyes'),
#                     (1, 'illness')],
#        'referential_gender': 'she/her'},
#  137: {'agentList': [(10, 'saw'),
#                      (6, 'said'),
#                      (3, 'stood'),
#                      (3, 'mean'),
#                      (3, 'thought'),
#                      (3, 'put'),
#                      (2, 'gave'),
#                      (2, 'walked'),
#                      (2, 'held'),
#                      (2, 'heard'),
#                      (2, 'come'),
#                      (2, 'bear'),
#                      (2, 'repeated'),
#                      (2, 'kept'),
#                      (2, 'understand'),
#                      (2, 'take'),
#                      (2, 'slipped'),
#                      (2, 'did'),
#                      (2, 'had'),
#                      (2, 'wanted')],
#        'count': 183,
#        'id': 137,
#        'max_proper_mention': 'Lebeziatnikov',
#        'modList': [(1, 'angry'),
#                    (1, 'witness'),
#                    (1, 'crazy'),
#                    (1, 'ready'),
#                    (1, 'minute'),
#                    (1, 'breathless'),
#                    (1, 'fact'),
#                    (1, 'ashamed'),
#                    (1, 'tired')],
#        'patientList': [(2, 'asked'),
#                        (1, 'call'),
#                        (1, 'repeated'),
#                        (1, 'take'),
#                        (1, 'watched'),
#                        (1, 'sent'),
#                        (1, 'struck'),
#                        (1, 'thanking'),
#                        (1, 'thank'),
#                        (1, 'show'),
#                        (1, 'express'),
#                        (1, 'believed'),
#                        (1, 'cried'),
#                        (1, 'addressing'),
#                        (1, 'called'),
#                        (1, 'Excuse'),
#                        (1, 'followed')],
#        'possList': [(6, 'hand'),
#                     (2, 'eyes'),
#                     (2, 'oath'),
#                     (1, 'hands'),
#                     (1, 'rudeness'),
#                     (1, 'dignity'),
#                     (1, 'money'),
#                     (1, 'words'),
#                     (1, 'mind'),
#                     (1, 'convictions'),
#                     (1, 'principles'),
#                     (1, 'left'),
#                     (1, 'secret'),
#                     (1, 'harangue'),
#                     (1, 'face'),
#                     (1, 'speech'),
#                     (1, 'line')],
#        'referential_gender': 'he/him/his'},
#  138: {'agentList': [(18, 'cried'),
#                      (14, 'had'),
#                      (8, 'has'),
#                      (8, 'said'),
#                      (8, 'told'),
#                      (8, 'rushed'),
#                      (7, 'began'),
#                      (6, 'put'),
#                      (6, 'heard'),
#                      (6, 'seemed'),
#                      (6, 'ran'),
#                      (6, 'took'),
#                      (5, 'understand'),
#                      (5, 'begin'),
#                      (5, 'see'),
#                      (5, 'die'),
#                      (4, 'stood'),
#                      (4, 'shouted'),
#                      (4, 'looked'),
#                      (4, 'used')],
#        'count': 843,
#        'id': 138,
#        'max_proper_mention': 'Katerina Ivanovna',
#        'modList': [(2, 'person'),
#                    (2, 'daughter'),
#                    (2, 'unjust'),
#                    (2, 'able'),
#                    (2, 'anxious'),
#                    (2, 'mad'),
#                    (1, 'magnanimous'),
#                    (1, 'full'),
#                    (1, 'lady'),
#                    (1, 'irritable'),
#                    (1, 'younger'),
#                    (1, 'woman'),
#                    (1, 'landlady'),
#                    (1, 'busy'),
#                    (1, 'unwilling'),
#                    (1, 'unhappy'),
#                    (1, 'pure'),
#                    (1, 'angry'),
#                    (1, 'good'),
#                    (1, 'bold')],
#        'patientList': [(3, 'blame'),
#                        (3, 'brought'),
#                        (3, 'respected'),
#                        (3, 'tell'),
#                        (3, 'help'),
#                        (2, 'saw'),
#                        (2, 'recognised'),
#                        (2, 'compensate'),
#                        (2, 'see'),
#                        (2, 'restrain'),
#                        (2, 'waved'),
#                        (2, 'cut'),
#                        (1, 'used'),
#                        (1, 'wound'),
#                        (1, 'treated'),
#                        (1, 'comforts'),
#                        (1, 'got'),
#                        (1, 'smartened'),
#                        (1, 'asking'),
#                        (1, 'needed')],
#        'possList': [(10, 'hands'),
#                     (10, 'father'),
#                     (9, 'husband'),
#                     (8, 'head'),
#                     (7, 'chest'),
#                     (6, 'eyes'),
#                     (5, 'mind'),
#                     (4, 'cheeks'),
#                     (4, 'face'),
#                     (4, 'body'),
#                     (4, 'knees'),
#                     (4, 'room'),
#                     (4, 'lips'),
#                     (3, 'stockings'),
#                     (3, 'arms'),
#                     (3, 'children'),
#                     (3, 'hand'),
#                     (3, 'feelings'),
#                     (2, 'breathing'),
#                     (2, 'papa')],
#        'referential_gender': 'she/her'},
#  139: {'agentList': [(4, 'said'),
#                      (4, 'looked'),
#                      (3, 'read'),
#                      (3, 'stopped'),
#                      (3, 'has'),
#                      (3, 'gave'),
#                      (2, 'had'),
#                      (2, 'got'),
#                      (2, 'laid'),
#                      (2, 'comes'),
#                      (1, 'attained'),
#                      (1, '’s'),
#                      (1, 'made'),
#                      (1, 'drove'),
#                      (1, 'speaking'),
#                      (1, 'get'),
#                      (1, 'came'),
#                      (1, 'walked'),
#                      (1, 'comforts'),
#                      (1, 'gives')],
#        'count': 128,
#        'id': 139,
#        'max_proper_mention': 'Sonia',
#        'modList': [(1, 'creature'),
#                    (1, 'unsteadier'),
#                    (1, 'bankrupt'),
#                    (1, 'girl')],
#        'patientList': [(1, 'paid'),
#                        (1, 'drove'),
#                        (1, 'reviling'),
#                        (1, 'take'),
#                        (1, 'see'),
#                        (1, 'ask'),
#                        (1, 'have'),
#                        (1, 'carry'),
#                        (1, 'carried'),
#                        (1, 'laid'),
#                        (1, 'find'),
#                        (1, 'reached'),
#                        (1, 'saw'),
#                        (1, 'noticed'),
#                        (1, 'recognising'),
#                        (1, 'seen'),
#                        (1, 'recognised')],
#        'possList': [(3, 'father'),
#                     (2, 'cape'),
#                     (2, 'shoes'),
#                     (1, 'education'),
#                     (1, 'kerchief'),
#                     (1, 'bed'),
#                     (1, 'feet'),
#                     (1, 'account'),
#                     (1, 'own'),
#                     (1, 'money'),
#                     (1, 'hands'),
#                     (1, 'last'),
#                     (1, 'appearance'),
#                     (1, 'foot'),
#                     (1, 'heart'),
#                     (1, 'fate'),
#                     (1, 'question'),
#                     (1, 'head'),
#                     (1, 'face'),
#                     (1, 'bewildered')],
#        'referential_gender': 'she/her'},
#  141: {'agentList': [],
#        'count': 2,
#        'id': 141,
#        'max_proper_mention': 'Ivan Ivanitch Klopstock',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'she/her'},
#  142: {'agentList': [],
#        'count': 7,
#        'id': 142,
#        'max_proper_mention': '....',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'she/her'},
#  143: {'agentList': [(1, 'took')],
#        'count': 3,
#        'id': 143,
#        'max_proper_mention': 'Darya Frantsovna',
#        'modList': [],
#        'patientList': [(1, 'backed')],
#        'possList': [],
#        'referential_gender': 'she/her'},
#  144: {'agentList': [(1, 'hear')],
#        'count': 2,
#        'id': 144,
#        'max_proper_mention': 'Amalia Fyodorovna',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'they/them/their'},
#  145: {'agentList': [(1, 'ran'), (1, 'leaves'), (1, 'gone')],
#        'count': 12,
#        'id': 145,
#        'max_proper_mention': 'Kapernaumov',
#        'modList': [(1, 'man'), (1, 'deaf')],
#        'patientList': [(1, 'Ask')],
#        'possList': [(1, 'door')],
#        'referential_gender': 'she/her'},
#  146: {'agentList': [],
#        'count': 4,
#        'id': 146,
#        'max_proper_mention': 'Ivan Afanasyvitch',
#        'modList': [(1, 'wax')],
#        'patientList': [(1, 'know')],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  147: {'agentList': [(3, 'says'),
#                      (1, 'resting'),
#                      (1, 'went'),
#                      (1, 'promise'),
#                      (1, 'got'),
#                      (1, 'dying'),
#                      (1, 'die'),
#                      (1, 'had'),
#                      (1, 'abandoned'),
#                      (1, 'known')],
#        'count': 34,
#        'id': 147,
#        'max_proper_mention': 'Semyon Zaharovitch',
#        'modList': [(1, 'tired')],
#        'patientList': [(1, 'went'),
#                        (1, 'led'),
#                        (1, 'remembers'),
#                        (1, 'abandoned'),
#                        (1, 'Turn')],
#        'possList': [(3, 'excellency'),
#                     (1, 'work'),
#                     (1, 'study'),
#                     (1, 'services'),
#                     (1, 'propensity'),
#                     (1, 'word'),
#                     (1, 'weakness'),
#                     (1, 'death'),
#                     (1, 'daughter')],
#        'referential_gender': 'he/him/his'},
#  149: {'agentList': [],
#        'count': 5,
#        'id': 149,
#        'max_proper_mention': 'Kozel',
#        'modList': [],
#        'patientList': [],
#        'possList': [(3, 'house')],
#        'referential_gender': 'he/him/his'},
#  150: {'agentList': [],
#        'count': 3,
#        'id': 150,
#        'max_proper_mention': 'Amalia Lippevechsel',
#        'modList': [],
#        'patientList': [],
#        'possList': [(1, 'flat')],
#        'referential_gender': 'they/them/their'},
#  151: {'agentList': [(8, 'went'),
#                      (6, 'brought'),
#                      (6, 'have'),
#                      (5, 'came'),
#                      (5, 'said'),
#                      (4, 'looked'),
#                      (4, 'standing'),
#                      (3, 'set'),
#                      (3, 'felt'),
#                      (3, 'cried'),
#                      (3, 'stood'),
#                      (3, 'left'),
#                      (3, 'tell'),
#                      (3, 'answered'),
#                      (3, 'returned'),
#                      (3, 'know'),
#                      (2, 'think'),
#                      (2, 'take'),
#                      (2, 'began'),
#                      (2, 'want')],
#        'count': 228,
#        'id': 151,
#        'max_proper_mention': 'Nastasya',
#        'modList': [(1, 'pleased'),
#                    (1, 'woman'),
#                    (1, 'fool'),
#                    (1, 'clever'),
#                    (1, 'girl'),
#                    (1, 'eager'),
#                    (1, 'fascinated'),
#                    (1, 'specimens'),
#                    (1, 'bashful'),
#                    (1, 'crowded')],
#        'patientList': [(2, 'asked'),
#                        (1, 'recognised'),
#                        (1, 'fetch'),
#                        (1, 'overcome'),
#                        (1, 'given'),
#                        (1, 'amused'),
#                        (1, 'motioned'),
#                        (1, 'scolding'),
#                        (1, 'retorted'),
#                        (1, 'shaking'),
#                        (1, 'remembered'),
#                        (1, 'tell'),
#                        (1, 'wanted'),
#                        (1, 'observed'),
#                        (1, 'beat'),
#                        (1, 'plying'),
#                        (1, 'assure'),
#                        (1, 'told')],
#        'possList': [(2, 'eyes'),
#                     (1, 'teapot'),
#                     (1, 'money'),
#                     (1, 'copecks'),
#                     (1, 'pot'),
#                     (1, 'goodness'),
#                     (1, 'absence'),
#                     (1, 'fist'),
#                     (1, 'giggle'),
#                     (1, 'scrutiny'),
#                     (1, 'landlady'),
#                     (1, 'nonsense'),
#                     (1, 'fingers'),
#                     (1, 'dear'),
#                     (1, 'temper'),
#                     (1, 'name'),
#                     (1, 'delight'),
#                     (1, 'sock'),
#                     (1, 'back'),
#                     (1, 'story')],
#        'referential_gender': 'she/her'},
#  152: {'agentList': [(1, 'means'),
#                      (1, 'had'),
#                      (1, 'shaved'),
#                      (1, 'locked'),
#                      (1, 'made'),
#                      (1, 'liking')],
#        'count': 17,
#        'id': 152,
#        'max_proper_mention': 'Praskovya Pavlovna',
#        'modList': [(1, 'foolish'), (1, 'jealous'), (1, 'gossip')],
#        'patientList': [(1, 'thank'), (1, 'locked')],
#        'possList': [(1, 'husband'), (1, 'parlour')],
#        'referential_gender': 'she/her'},
#  153: {'agentList': [(15, 'had'),
#                      (14, 'know'),
#                      (13, 'heard'),
#                      (13, 'come'),
#                      (10, 'think'),
#                      (9, 'made'),
#                      (8, 'said'),
#                      (8, 'has'),
#                      (8, 'going'),
#                      (7, 'believe'),
#                      (6, 'asked'),
#                      (6, 'began'),
#                      (6, 'wanted'),
#                      (5, 'see'),
#                      (5, 'go'),
#                      (5, 'have'),
#                      (5, 'went'),
#                      (4, 'wrote'),
#                      (4, 'given'),
#                      (4, 'answered')],
#        'count': 909,
#        'id': 153,
#        'max_proper_mention': 'Rodya',
#        'modList': [(11, 'man'),
#                    (3, 'kind'),
#                    (2, 'ill'),
#                    (2, 'right'),
#                    (2, 'sure'),
#                    (2, 'angry'),
#                    (2, 'afraid'),
#                    (2, 'glad'),
#                    (1, 'opponent'),
#                    (1, 'clever'),
#                    (1, 'cautious'),
#                    (1, 'student'),
#                    (1, 'generous'),
#                    (1, 'delicate'),
#                    (1, 'anxious'),
#                    (1, 'comfort'),
#                    (1, 'conscious'),
#                    (1, 'fiancé'),
#                    (1, 'irritable'),
#                    (1, 'dead')],
#        'patientList': [(4, 'loves'),
#                        (3, 'tell'),
#                        (3, 'know'),
#                        (3, 'see'),
#                        (3, 'ask'),
#                        (3, 'invited'),
#                        (2, 'love'),
#                        (2, 'occupied'),
#                        (2, 'leave'),
#                        (2, 'seeing'),
#                        (2, 'marry'),
#                        (2, 'marrying'),
#                        (2, 'reconciled'),
#                        (2, 'wrote'),
#                        (2, 'abandon'),
#                        (2, 'admire'),
#                        (2, 'impressed'),
#                        (2, 'reassured'),
#                        (2, 'awaiting'),
#                        (2, 'asked')],
#        'possList': [(5, 'way'),
#                     (4, 'work'),
#                     (4, 'father'),
#                     (3, 'sister'),
#                     (3, 'visit'),
#                     (3, 'career'),
#                     (3, 'power'),
#                     (3, 'friend'),
#                     (2, 'feelings'),
#                     (2, 'side'),
#                     (2, 'mind'),
#                     (2, 'studies'),
#                     (2, 'hand'),
#                     (2, 'opinion'),
#                     (2, 'fortune'),
#                     (2, 'presence'),
#                     (2, 'mamma'),
#                     (2, 'betrothed'),
#                     (2, 'room'),
#                     (2, 'request')],
#        'referential_gender': 'he/him/his'},
#  154: {'agentList': [(26, 'said'),
#                      (15, 'see'),
#                      (12, 'know'),
#                      (11, 'has'),
#                      (10, 'have'),
#                      (10, 'believe'),
#                      (10, 'looked'),
#                      (9, 'come'),
#                      (9, 'answered'),
#                      (8, 'had'),
#                      (8, 'want'),
#                      (8, 'cried'),
#                      (7, 'put'),
#                      (7, 'think'),
#                      (7, 'tell'),
#                      (7, 'stood'),
#                      (6, 'loves'),
#                      (6, 'went'),
#                      (6, 'saw'),
#                      (5, 'took')],
#        'count': 1098,
#        'id': 154,
#        'max_proper_mention': 'Dounia',
#        'modList': [(5, 'glad'),
#                    (3, 'afraid'),
#                    (2, 'cause'),
#                    (2, 'angel'),
#                    (2, 'ready'),
#                    (2, 'unhappy'),
#                    (2, 'sure'),
#                    (1, 'clever'),
#                    (1, 'talkative'),
#                    (1, 'fond'),
#                    (1, 'girl'),
#                    (1, 'excitement'),
#                    (1, 'sort'),
#                    (1, 'same'),
#                    (1, 'nigger'),
#                    (1, 'hasty'),
#                    (1, 'upset'),
#                    (1, 'unhappier'),
#                    (1, 'right'),
#                    (1, 'pale')],
#        'patientList': [(10, 'tell'),
#                        (5, 'cried'),
#                        (4, 'love'),
#                        (3, 'take'),
#                        (3, 'embraced'),
#                        (3, 'sell'),
#                        (3, 'observed'),
#                        (3, 'offended'),
#                        (3, 'told'),
#                        (2, 'know'),
#                        (2, 'forgive'),
#                        (2, 'saw'),
#                        (2, 'see'),
#                        (2, 'call'),
#                        (2, 'guard'),
#                        (2, 'insulted'),
#                        (2, 'reconciled'),
#                        (2, 'reminded'),
#                        (2, 'tempted'),
#                        (2, 'asked')],
#        'possList': [(22, 'brother'),
#                     (14, 'mother'),
#                     (13, 'eyes'),
#                     (8, 'hand'),
#                     (5, 'husband'),
#                     (5, 'life'),
#                     (5, 'face'),
#                     (3, 'clothes'),
#                     (3, 'forgiveness'),
#                     (3, 'mistrustfully'),
#                     (3, 'image'),
#                     (2, 'things'),
#                     (2, 'reputation'),
#                     (2, 'love'),
#                     (2, 'soul'),
#                     (2, 'decision'),
#                     (2, 'sake'),
#                     (2, 'family'),
#                     (2, 'watch'),
#                     (2, 'letter')],
#        'referential_gender': 'she/her'},
#  155: {'agentList': [],
#        'count': 3,
#        'id': 155,
#        'max_proper_mention': 'Vassily Ivanovitch Vahrushin',
#        'modList': [(1, 'man')],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  156: {'agentList': [(27, 'have'),
#                      (18, 'know'),
#                      (14, 'said'),
#                      (13, 'tell'),
#                      (12, 'told'),
#                      (11, 'had'),
#                      (9, 'see'),
#                      (9, 'like'),
#                      (9, 'think'),
#                      (9, 'saw'),
#                      (8, 'want'),
#                      (8, 'do'),
#                      (7, 'looked'),
#                      (7, 'get'),
#                      (7, 'asked'),
#                      (7, 'sat'),
#                      (6, 'come'),
#                      (6, 'go'),
#                      (6, 'believe'),
#                      (5, 'made')],
#        'count': 1049,
#        'id': 156,
#        'max_proper_mention': 'Svidrigaïlov',
#        'modList': [(6, 'afraid'),
#                    (4, 'fond'),
#                    (3, 'man'),
#                    (2, 'person'),
#                    (2, 'capable'),
#                    (2, 'cause'),
#                    (2, 'sure'),
#                    (2, 'drunk'),
#                    (2, 'able'),
#                    (2, 'terrible'),
#                    (1, 'father'),
#                    (1, 'head'),
#                    (1, 'neighbour'),
#                    (1, 'busy'),
#                    (1, 'sorry'),
#                    (1, 'means'),
#                    (1, 'intriguing'),
#                    (1, 'week'),
#                    (1, 'asleep'),
#                    (1, 'aware')],
#        'patientList': [(13, 'told'),
#                        (9, 'tell'),
#                        (5, 'kill'),
#                        (5, 'believe'),
#                        (4, 'save'),
#                        (3, 'see'),
#                        (3, 'seen'),
#                        (3, 'Tell'),
#                        (3, 'saved'),
#                        (2, 'interested'),
#                        (2, 'saw'),
#                        (2, 'watched'),
#                        (2, 'give'),
#                        (2, 'love'),
#                        (2, 'take'),
#                        (2, 'warn'),
#                        (1, 'reproached'),
#                        (1, 'reminding'),
#                        (1, 'telling'),
#                        (1, 'noticed')],
#        'possList': [(7, 'eyes'),
#                     (6, 'face'),
#                     (3, 'wife'),
#                     (3, 'soul'),
#                     (3, 'money'),
#                     (3, 'betrothed'),
#                     (3, 'rooms'),
#                     (3, 'brother'),
#                     (2, 'business'),
#                     (2, 'way'),
#                     (2, 'mouth'),
#                     (2, 'own'),
#                     (2, 'position'),
#                     (2, 'head'),
#                     (2, 'sister'),
#                     (2, 'conviction'),
#                     (2, 'designs'),
#                     (2, 'knee'),
#                     (2, 'letter'),
#                     (2, 'heart')],
#        'referential_gender': 'he/him/his'},
#  157: {'agentList': [(6, 'had'),
#                      (5, 'went'),
#                      (5, 'came'),
#                      (4, 'left'),
#                      (3, 'told'),
#                      (3, 'died'),
#                      (3, 'used'),
#                      (3, 'got'),
#                      (3, 'gave'),
#                      (2, 'reading'),
#                      (2, 'bought'),
#                      (2, 'done'),
#                      (2, 'kept'),
#                      (1, 'overheard'),
#                      (1, 'refused'),
#                      (1, 'written'),
#                      (1, 'reproached'),
#                      (1, 'said'),
#                      (1, 'knelt'),
#                      (1, 'embraced')],
#        'count': 210,
#        'id': 157,
#        'max_proper_mention': 'Marfa Petrovna',
#        'modList': [(3, 'pleased'),
#                    (3, 'woman'),
#                    (2, 'older'),
#                    (2, 'afraid'),
#                    (1, 'convinced'),
#                    (1, 'busy'),
#                    (1, 'warmth'),
#                    (1, 'fond'),
#                    (1, 'times'),
#                    (1, 'hand'),
#                    (1, 'disinclined'),
#                    (1, 'dead'),
#                    (1, 'instance'),
#                    (1, 'sensible'),
#                    (1, 'proud'),
#                    (1, 'angry'),
#                    (1, 'weak')],
#        'patientList': [(2, 'beat'),
#                        (2, 'buried'),
#                        (2, 'tell'),
#                        (1, 'entreating'),
#                        (1, 'taken'),
#                        (1, 'said'),
#                        (1, 'expected'),
#                        (1, 'forced'),
#                        (1, 'show'),
#                        (1, 'missing'),
#                        (1, 'Missing'),
#                        (1, 'saw'),
#                        (1, 'hear'),
#                        (1, 'asking'),
#                        (1, 'tease'),
#                        (1, 'want'),
#                        (1, 'remembered'),
#                        (1, 'left'),
#                        (1, 'See'),
#                        (1, 'married')],
#        'possList': [(3, 'husband'),
#                     (3, 'death'),
#                     (2, 'behavior'),
#                     (2, 'exertions'),
#                     (2, 'money'),
#                     (2, 'house'),
#                     (1, 'departure'),
#                     (1, 'strength'),
#                     (1, 'duty'),
#                     (1, 'feelings'),
#                     (1, 'character'),
#                     (1, 'head'),
#                     (1, 'act'),
#                     (1, 'expression'),
#                     (1, 'hands'),
#                     (1, 'face'),
#                     (1, 'train'),
#                     (1, 'pardon'),
#                     (1, 'side'),
#                     (1, 'will')],
#        'referential_gender': 'she/her'},
#  159: {'agentList': [(9, 'went'),
#                      (6, 'said'),
#                      (6, 'made'),
#                      (6, 'saw'),
#                      (5, 'come'),
#                      (4, 'find'),
#                      (4, 'began'),
#                      (4, 'tell'),
#                      (4, 'pass'),
#                      (4, 'sent'),
#                      (4, 'beg'),
#                      (4, 'gave'),
#                      (3, 'looked'),
#                      (3, 'had'),
#                      (3, 'taken'),
#                      (3, 'paused'),
#                      (3, 'found'),
#                      (3, 'replied'),
#                      (3, 'put'),
#                      (3, 'standing')],
#        'count': 472,
#        'id': 159,
#        'max_proper_mention': 'Pyotr Petrovitch',
#        'modList': [(2, 'glad'),
#                    (2, 'ready'),
#                    (1, 'stranger'),
#                    (1, 'guardian'),
#                    (1, 'delighted'),
#                    (1, 'mistaken'),
#                    (1, 'anxious'),
#                    (1, 'miles'),
#                    (1, 'man'),
#                    (1, 'prepared'),
#                    (1, 'convinced'),
#                    (1, 'aware'),
#                    (1, 'unable'),
#                    (1, 'ashamed'),
#                    (1, 'immovable'),
#                    (1, 'responsible'),
#                    (1, 'slanderer'),
#                    (1, 'scoundrel'),
#                    (1, 'drunk'),
#                    (1, 'drunkard')],
#        'patientList': [(5, 'struck'),
#                        (4, 'Excuse'),
#                        (3, 'told'),
#                        (3, 'asked'),
#                        (3, 'Allow'),
#                        (2, 'refuse'),
#                        (1, 'pronounced'),
#                        (1, 'began'),
#                        (1, 'assured'),
#                        (1, 'offended'),
#                        (1, 'get'),
#                        (1, 'rig'),
#                        (1, 'interests'),
#                        (1, 'strikes'),
#                        (1, 'send'),
#                        (1, 'restrain'),
#                        (1, 'seen'),
#                        (1, 'promised'),
#                        (1, 'throw'),
#                        (1, 'marrying')],
#        'possList': [(3, 'word'),
#                     (3, 'way'),
#                     (2, 'appearance'),
#                     (2, 'friend'),
#                     (2, 'words'),
#                     (2, 'neighbour'),
#                     (2, 'mind'),
#                     (2, 'illness'),
#                     (2, 'book'),
#                     (1, 'shoulders'),
#                     (1, 'arrival'),
#                     (1, 'astonishment'),
#                     (1, 'pillow'),
#                     (1, 'days'),
#                     (1, 'betrothed'),
#                     (1, 'complacent'),
#                     (1, 'clothes'),
#                     (1, 'hands'),
#                     (1, 'hand'),
#                     (1, 'attire')],
#        'referential_gender': 'he/him/his'},
#  160: {'agentList': [(2, 'sign'),
#                      (1, 'trust'),
#                      (1, 'knows'),
#                      (1, 'refuse'),
#                      (1, 'sent'),
#                      (1, 'scrawl'),
#                      (1, 'waiting')],
#        'count': 27,
#        'id': 160,
#        'max_proper_mention': 'Afanasy Ivanovitch',
#        'modList': [(1, 'conscious')],
#        'patientList': [(1, 'know'), (1, 'knows'), (1, 'take')],
#        'possList': [(1, 'name'), (1, 'travels'), (1, 'hand')],
#        'referential_gender': 'he/him/his'},
#  161: {'agentList': [(41, 'said'),
#                      (37, 'went'),
#                      (25, 'know'),
#                      (24, 'thought'),
#                      (23, 'come'),
#                      (20, 'asked'),
#                      (18, 'understand'),
#                      (16, 'looked'),
#                      (16, 'saw'),
#                      (15, 'began'),
#                      (15, 'have'),
#                      (15, 'cried'),
#                      (15, 'see'),
#                      (14, 'felt'),
#                      (13, 'answered'),
#                      (13, 'stood'),
#                      (13, 'go'),
#                      (12, 'had'),
#                      (11, 'turned'),
#                      (11, 'seen')],
#        'count': 1676,
#        'id': 161,
#        'max_proper_mention': 'Raskolnikov',
#        'modList': [(6, 'afraid'),
#                    (5, 'ashamed'),
#                    (5, 'glad'),
#                    (4, 'sure'),
#                    (3, 'frightened'),
#                    (3, 'mad'),
#                    (2, 'tired'),
#                    (2, 'wrong'),
#                    (2, 'aware'),
#                    (2, 'anxious'),
#                    (2, 'surprised'),
#                    (2, 'foolish'),
#                    (2, 'person'),
#                    (2, 'ready'),
#                    (1, 'fool'),
#                    (1, 'unworthy'),
#                    (1, 'worthy'),
#                    (1, 'pale'),
#                    (1, 'listless'),
#                    (1, 'lodging')],
#        'patientList': [(10, 'see'),
#                        (7, 'cried'),
#                        (6, 'tell'),
#                        (6, 'told'),
#                        (3, 'thought'),
#                        (3, 'struck'),
#                        (3, 'taken'),
#                        (2, 'worry'),
#                        (2, 'Excuse'),
#                        (2, 'Tell'),
#                        (2, 'killed'),
#                        (2, 'forgive'),
#                        (2, 'blamed'),
#                        (2, 'exclaimed'),
#                        (2, 'added'),
#                        (2, 'crossing'),
#                        (2, 'observed'),
#                        (2, 'crushed'),
#                        (2, 'reassure'),
#                        (2, 'watching')],
#        'possList': [(20, 'eyes'),
#                     (15, 'sister'),
#                     (14, 'mother'),
#                     (12, 'heart'),
#                     (9, 'mind'),
#                     (8, 'face'),
#                     (5, 'illness'),
#                     (5, 'lips'),
#                     (5, 'hands'),
#                     (4, 'life'),
#                     (4, 'dear'),
#                     (4, 'room'),
#                     (4, 'head'),
#                     (4, 'words'),
#                     (3, 'death'),
#                     (3, 'sentence'),
#                     (3, 'name'),
#                     (3, 'legs'),
#                     (3, 'way'),
#                     (3, 'article')],
#        'referential_gender': 'he/him/his'},
#  162: {'agentList': [],
#        'count': 3,
#        'id': 162,
#        'max_proper_mention': 'Vassilyevsky Ostrov',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  163: {'agentList': [(4, 'said'),
#                      (3, 'think'),
#                      (2, 'has'),
#                      (2, 'puts'),
#                      (2, 'let'),
#                      (2, 'seemed'),
#                      (2, 'know'),
#                      (2, 'have'),
#                      (2, 'seem'),
#                      (2, 'wrote'),
#                      (2, 'made'),
#                      (2, 'throw'),
#                      (2, 'go'),
#                      (2, 'hope'),
#                      (2, 'got'),
#                      (2, 'going'),
#                      (2, 'done'),
#                      (2, 'rejoice'),
#                      (2, 'want'),
#                      (1, 'offer')],
#        'count': 211,
#        'id': 163,
#        'max_proper_mention': 'Luzhin',
#        'modList': [(2, 'man'),
#                    (2, 'sorry'),
#                    (1, 'sure'),
#                    (1, 'aware'),
#                    (1, 'match'),
#                    (1, 'surprised'),
#                    (1, 'able'),
#                    (1, 'consequence'),
#                    (1, 'worth'),
#                    (1, 'ashamed'),
#                    (1, 'stupid'),
#                    (1, 'happy')],
#        'patientList': [(2, 'tell'),
#                        (1, 'damned'),
#                        (1, 'meet'),
#                        (1, 'murdered'),
#                        (1, 'scanning'),
#                        (1, 'finding'),
#                        (1, 'seen'),
#                        (1, 'cut'),
#                        (1, 'settle'),
#                        (1, 'detest'),
#                        (1, 'marrying'),
#                        (1, 'setting'),
#                        (1, 'Excuse'),
#                        (1, 'found'),
#                        (1, 'spared'),
#                        (1, 'cried'),
#                        (1, 'bound'),
#                        (1, 'led'),
#                        (1, 'marry'),
#                        (1, 'deceived')],
#        'possList': [(4, 'mother'),
#                     (3, 'sister'),
#                     (3, 'letter'),
#                     (2, 'money'),
#                     (2, 'desire'),
#                     (2, 'conviction'),
#                     (1, 'generosity'),
#                     (1, 'buttonhole'),
# ...
#                      (1, 'make'),
#                      (1, 'told'),
#                      (1, 'has')],
#        'count': 26,
#        'id': 268,
#        'max_proper_mention': 'Madame Resslich',
#        'modList': [(1, 'hussy'), (1, 'woman')],
#        'patientList': [(1, 'know'), (1, 'drowned')],
#        'possList': [(1, 'mind')],
#        'referential_gender': 'she/her'},
#  270: {'agentList': [],
#        'count': 2,
#        'id': 270,
#        'max_proper_mention': 'Romeo',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'she/her'},
#  274: {'agentList': [(2, 'had'), (1, 'left')],
#        'count': 4,
#        'id': 274,
#        'max_proper_mention': 'Newton',
#        'modList': [],
#        'patientList': [],
#        'possList': [(1, 'discoveries')],
#        'referential_gender': 'he/him/his'},
#  278: {'agentList': [(3, 'had'),
#                      (2, 'strangled'),
#                      (1, '’s'),
#                      (1, 'happened'),
#                      (1, 'brought'),
#                      (1, 'felt'),
#                      (1, 'seen'),
#                      (1, 'done'),
#                      (1, 'attracted')],
#        'count': 21,
#        'id': 278,
#        'max_proper_mention': 'Napoleon',
#        'modList': [],
#        'patientList': [(1, 'beaten'),
#                        (1, 'taken'),
#                        (1, 'brought'),
#                        (1, 'struck')],
#        'possList': [(2, 'career'), (1, 'example')],
#        'referential_gender': 'he/him/his'},
#  279: {'agentList': [(1, 'come')],
#        'count': 7,
#        'id': 279,
#        'max_proper_mention': 'Lazarus',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  282: {'agentList': [(1, 'sent')],
#        'count': 4,
#        'id': 282,
#        'max_proper_mention': 'Providence',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  285: {'agentList': [(11, 'thought'),
#                      (9, 'went'),
#                      (8, 'took'),
#                      (8, 'know'),
#                      (8, 'came'),
#                      (7, 'said'),
#                      (6, 'heard'),
#                      (6, 'believe'),
#                      (6, 'going'),
#                      (6, 'had'),
#                      (6, 'got'),
#                      (6, 'turned'),
#                      (5, 'put'),
#                      (5, 'say'),
#                      (5, 'felt'),
#                      (5, 'began'),
#                      (4, 'looked'),
#                      (4, 'saw'),
#                      (4, 'walked'),
#                      (4, 'sat')],
#        'count': 452,
#        'id': 285,
#        'max_proper_mention': 'Svidrigaïlov',
#        'modList': [(4, 'man'),
#                    (2, 'awake'),
#                    (1, 'right'),
#                    (1, 'wrong'),
#                    (1, 'fond'),
#                    (1, 'monster'),
#                    (1, 'adaptable'),
#                    (1, 'bear'),
#                    (1, 'interested'),
#                    (1, 'sick'),
#                    (1, 'alone'),
#                    (1, 'stock'),
#                    (1, 'sure'),
#                    (1, 'convinced'),
#                    (1, 'cool'),
#                    (1, 'quiet'),
#                    (1, 'cause'),
#                    (1, 'specimen'),
#                    (1, 'fascinating'),
#                    (1, 'wet')],
#        'patientList': [(2, 'trouble'),
#                        (2, 'see'),
#                        (2, 'seen'),
#                        (2, 'muttered'),
#                        (2, 'know'),
#                        (2, 'answered'),
#                        (1, 'dislike'),
#                        (1, 'cried'),
#                        (1, 'interrupted'),
#                        (1, 'tell'),
#                        (1, 'told'),
#                        (1, 'affected'),
#                        (1, 'go'),
#                        (1, 'restrain'),
#                        (1, 'gave'),
#                        (1, 'visit'),
#                        (1, 'puzzled'),
#                        (1, 'disturb'),
#                        (1, 'does'),
#                        (1, 'help')],
#        'possList': [(4, 'wife'),
#                     (3, 'hat'),
#                     (3, 'betrothed'),
#                     (3, 'hand'),
#                     (2, 'head'),
#                     (2, 'departure'),
#                     (2, 'greetings'),
#                     (2, 'chest'),
#                     (2, 'overcoat'),
#                     (2, 'pocket'),
#                     (1, 'question'),
#                     (1, 'questions'),
#                     (1, 'sister'),
#                     (1, 'property'),
#                     (1, 'heels'),
#                     (1, 'hope'),
#                     (1, 'doing'),
#                     (1, 'day'),
#                     (1, 'studying'),
#                     (1, 'mouth')],
#        'referential_gender': 'he/him/his'},
#  287: {'agentList': [(1, 'going'), (1, 'take'), (1, 'mean')],
#        'count': 4,
#        'id': 287,
#        'max_proper_mention': 'Berg',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  288: {'agentList': [(1, 'make')],
#        'count': 2,
#        'id': 288,
#        'max_proper_mention': 'Aniska',
#        'modList': [(1, 'dressmaker')],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  289: {'agentList': [],
#        'count': 2,
#        'id': 289,
#        'max_proper_mention': 'Filka',
#        'modList': [],
#        'patientList': [(1, 'forgetting')],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  292: {'agentList': [],
#        'count': 2,
#        'id': 292,
#        'max_proper_mention': 'Raphael',
#        'modList': [],
#        'patientList': [],
#        'possList': [(1, 'Madonna')],
#        'referential_gender': 'he/him/his'},
#  295: {'agentList': [(2, 'hanged'),
#                      (1, 'received'),
#                      (1, 'read'),
#                      (1, 'behaved'),
#                      (1, 'end'),
#                      (1, 'shouted'),
#                      (1, 'brought')],
#        'count': 25,
#        'id': 295,
#        'max_proper_mention': 'Philip',
#        'modList': [(1, 'sort'), (1, 'man')],
#        'patientList': [(1, 'read'), (1, 'hanged'), (1, 'blame'), (1, 'left')],
#        'possList': [(1, 'blows'),
#                     (1, 'death'),
#                     (1, 'defence'),
#                     (1, 'interests'),
#                     (1, 'habits')],
#        'referential_gender': 'he/him/his'},
#  297: {'agentList': [(1, 'let'), (1, 'live'), (1, 'have')],
#        'count': 9,
#        'id': 297,
#        'max_proper_mention': 'the Kapernaumovs',
#        'modList': [(1, 'people'), (1, 'kind')],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'they/them/their'},
#  299: {'agentList': [(1, 'heard'), (1, 'said'), (1, 'saith'), (1, 'read')],
#        'count': 18,
#        'id': 299,
#        'max_proper_mention': 'Martha',
#        'modList': [(1, 'dead')],
#        'patientList': [],
#        'possList': [(1, 'brother')],
#        'referential_gender': 'she/her'},
#  300: {'agentList': [(1, 'sat'), (1, 'fell'), (1, 'laid')],
#        'count': 8,
#        'id': 300,
#        'max_proper_mention': 'Mary',
#        'modList': [],
#        'patientList': [(1, 'come')],
#        'possList': [(1, 'weeping')],
#        'referential_gender': 'she/her'},
#  301: {'agentList': [(5, 'said'),
#                      (1, 'coming'),
#                      (1, 'saw'),
#                      (1, 'weeping'),
#                      (1, 'groaned'),
#                      (1, 'wept'),
#                      (1, 'loved'),
#                      (1, 'groaning'),
#                      (1, 'stinketh'),
#                      (1, 'lifted'),
#                      (1, 'spoken'),
#                      (1, 'cried'),
#                      (1, 'come'),
#                      (1, 'came'),
#                      (1, 'go'),
#                      (1, 'believed')],
#        'count': 38,
#        'id': 301,
#        'max_proper_mention': 'Jesus',
#        'modList': [],
#        'patientList': [(1, 'met'),
#                        (1, 'give'),
#                        (1, 'saw'),
#                        (1, 'laid'),
#                        (1, 'loved')],
#        'possList': [(1, 'feet'), (1, 'eyes'), (1, 'face')],
#        'referential_gender': 'he/him/his'},
#  304: {'agentList': [(1, 'surrendered')],
#        'count': 5,
#        'id': 304,
#        'max_proper_mention': 'General Mack',
#        'modList': [],
#        'patientList': [],
#        'possList': [(1, 'army')],
#        'referential_gender': 'he/him/his'},
#  306: {'agentList': [(1, 'left'),
#                      (1, 'devoted'),
#                      (1, 'wrote'),
#                      (1, 'said'),
#                      (1, 'go'),
#                      (1, 'entering'),
#                      (1, 'spared'),
#                      (1, 'written')],
#        'count': 9,
#        'id': 306,
#        'max_proper_mention': 'Terebyeva',
#        'modList': [],
#        'patientList': [(1, 'blamed')],
#        'possList': [(1, 'family'), (1, 'father'), (1, 'mother')],
#        'referential_gender': 'she/her'},
#  307: {'agentList': [(1, 'abandoned'), (1, 'told')],
#        'count': 5,
#        'id': 307,
#        'max_proper_mention': 'Varents',
#        'modList': [],
#        'patientList': [(1, 'married')],
#        'possList': [(1, 'children'), (1, 'husband')],
#        'referential_gender': 'she/her'},
#  311: {'agentList': [(1, 'brought')],
#        'count': 2,
#        'id': 311,
#        'max_proper_mention': 'The Pole',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  313: {'agentList': [],
#        'count': 2,
#        'id': 313,
#        'max_proper_mention': 'Johann',
#        'modList': [(1, 'burgomeister')],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  314: {'agentList': [],
#        'count': 3,
#        'id': 314,
#        'max_proper_mention': 'mademoiselle',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'she/her'},
#  317: {'agentList': [],
#        'count': 3,
#        'id': 317,
#        'max_proper_mention': 'our gracious Tsar himself',
#        'modList': [],
#        'patientList': [],
#        'possList': [(1, 'feet')],
#        'referential_gender': 'he/him/his'},
#  319: {'agentList': [],
#        'count': 2,
#        'id': 319,
#        'max_proper_mention': 'Madame Kobilatnikov',
#        'modList': [],
#        'patientList': [],
#        'possList': [(1, 'pocket')],
#        'referential_gender': 'she/her'},
#  327: {'agentList': [(1, 'gives'), (1, 'laughed'), (1, 'sounded'), (1, 'said')],
#        'count': 8,
#        'id': 327,
#        'max_proper_mention': 'Dr. B----n',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  329: {'agentList': [(1, 'drank'),
#                      (1, 'took'),
#                      (1, 'saw'),
#                      (1, 'turned'),
#                      (1, 'sang')],
#        'count': 8,
#        'id': 329,
#        'max_proper_mention': 'Katia',
#        'modList': [],
#        'patientList': [(1, 'saw'), (1, 'kissing'), (1, 'treated')],
#        'possList': [(1, 'glass')],
#        'referential_gender': 'she/her'},
#  330: {'agentList': [(1, 'know')],
#        'count': 9,
#        'id': 330,
#        'max_proper_mention': 'Schiller',
#        'modList': [(1, 'Schiller')],
#        'patientList': [],
#        'possList': [(1, 'outcries')],
#        'referential_gender': 'he/him/his'},
#  331: {'agentList': [(2, 'come'),
#                      (1, 'burst'),
#                      (1, 'wailed'),
#                      (1, 'came'),
#                      (1, 'was')],
#        'count': 6,
#        'id': 331,
#        'max_proper_mention': 'Parasha',
#        'modList': [],
#        'patientList': [(1, 'heard'), (1, 'leaving')],
#        'possList': [],
#        'referential_gender': 'she/her'},
#  332: {'agentList': [],
#        'count': 2,
#        'id': 332,
#        'max_proper_mention': 'the Sistine Madonna',
#        'modList': [],
#        'patientList': [],
#        'possList': [(1, 'face')],
#        'referential_gender': 'she/her'},
#  334: {'agentList': [(3, 'take'),
#                      (3, 'turned'),
#                      (2, 'walked'),
#                      (2, 'put'),
#                      (2, 'going'),
#                      (2, 'come'),
#                      (2, 'understand'),
#                      (2, 'see'),
#                      (1, 'observed'),
#                      (1, 'learnt'),
#                      (1, 'like'),
#                      (1, 'said'),
#                      (1, 'wanted'),
#                      (1, 'wished'),
#                      (1, 'call'),
#                      (1, 'assumed'),
#                      (1, 'refrained'),
#                      (1, '’re'),
#                      (1, 'warn'),
#                      (1, 'lock')],
#        'count': 76,
#        'id': 334,
#        'max_proper_mention': 'Raskolnikov',
#        'modList': [(1, '_'), (1, 'convinced'), (1, 'alone')],
#        'patientList': [(1, 'make'),
#                        (1, 'said'),
#                        (1, 'satisfied'),
#                        (1, 'devoured'),
#                        (1, 'follow'),
#                        (1, 'regard'),
#                        (1, 'believe'),
#                        (1, 'see'),
#                        (1, 'drew'),
#                        (1, 'convinced'),
#                        (1, 'met'),
#                        (1, 'avoid')],
#        'possList': [(4, 'sister'),
#                     (1, 'word'),
#                     (1, 'threat'),
#                     (1, 'room'),
#                     (1, 'suspicions'),
#                     (1, 'way'),
#                     (1, 'judgment')],
#        'referential_gender': 'he/him/his'},
#  335: {'agentList': [(1, 'like'), (1, 'observe')],
#        'count': 3,
#        'id': 335,
#        'max_proper_mention': 'Scoundrel',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  339: {'agentList': [(1, 'raised'), (1, 'say'), (1, 'cried')],
#        'count': 9,
#        'id': 339,
#        'max_proper_mention': 'Achilles',
#        'modList': [],
#        'patientList': [(1, 'struck')],
#        'possList': [(1, 'eyebrows'), (1, 'eyes')],
#        'referential_gender': 'he/him/his'},
#  342: {'agentList': [(1, 'had')],
#        'count': 2,
#        'id': 342,
#        'max_proper_mention': 'Lizaveta’s',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'she/her'},
#  346: {'agentList': [(1, 'left'), (1, 'feeling')],
#        'count': 3,
#        'id': 346,
#        'max_proper_mention': 'Hulloa',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  347: {'agentList': [(1, 'proved')],
#        'count': 2,
#        'id': 347,
#        'max_proper_mention': 'Dr. Zossimov',
#        'modList': [],
#        'patientList': [(1, 'invited')],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  350: {'agentList': [(1, 'come')],
#        'count': 2,
#        'id': 350,
#        'max_proper_mention': 'Easter',
#        'modList': [],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'she/her'},
#  351: {'agentList': [],
#        'count': 2,
#        'id': 351,
#        'max_proper_mention': 'Abraham',
#        'modList': [],
#        'patientList': [],
#        'possList': [(1, 'flocks')],
#        'referential_gender': 'he/him/his'},
#  352: {'agentList': [],
#        'count': 3,
#        'id': 352,
#        'max_proper_mention': 'Gutenberg Literary Archive Foundation',
#        'modList': [],
#        'patientList': [(1, 'Contact')],
#        'possList': [],
#        'referential_gender': 'he/him/his'},
#  354: {'agentList': [(1, 'produced'), (1, 'distributed')],
#        'count': 2,
#        'id': 354,
#        'max_proper_mention': 'Hart',
#        'modList': [(1, 'originator')],
#        'patientList': [],
#        'possList': [],
#        'referential_gender': 'he/him/his'}}

# %%
# show all max_proper_mentions in character_data
for cid, character in list(character_data.items())[:10]:
    print(f"{cid} - {character['max_proper_mention']}")
# Out:
# 131 - Raskolnikov
# 161 - Raskolnikov
# 249 - Sonia
# 217 - Razumihin
# 213 - Porfiry
# 154 - Dounia
# 156 - Svidrigaïlov
# 153 - Rodya
# 164 - Avdotya Romanovna
# 138 - Katerina Ivanovna

# %%
verb_data = find_verb_usage(character_data)

# %%
pprint(verb_data)
# Out:
# {'agent': {'abandon': [(268, 'Madame Resslich')],
#            'abandoned': [(147, 'Semyon Zaharovitch'), (307, 'Varents')],
#            'acquired': [(247, 'Amalia Ivanovna')],
#            'added': [(201, 'Zossimov'), (191, 'Nikodim Fomitch')],
#            'allow': [(225, 'Lebeziatnikov'), (134, 'God')],
#            'answered': [(161, 'Raskolnikov'),
#                         (217, 'Razumihin'),
#                         (154, 'Dounia'),
#                         (153, 'Rodya'),
#                         (207, 'Zametov'),
#                         (151, 'Nastasya')],
#            'arranged': [(268, 'Madame Resslich')],
#            'asked': [(131, 'Raskolnikov'),
#                      (161, 'Raskolnikov'),
#                      (249, 'Sonia'),
#                      (156, 'Svidrigaïlov'),
#                      (153, 'Rodya'),
#                      (164, 'Avdotya Romanovna'),
#                      (225, 'Lebeziatnikov'),
#                      (267, 'Raskolnikov'),
#                      (191, 'Nikodim Fomitch')],
#            'assumed': [(334, 'Raskolnikov')],
#            'attached': [(225, 'Lebeziatnikov')],
#            'attained': [(139, 'Sonia')],
#            'attracted': [(278, 'Napoleon')],
#            'bade': [(198, 'Christ')],
#            'bear': [(137, 'Lebeziatnikov')],
#            'beat': [(176, 'Mikolka')],
#            'became': [(111, 'Dostoevsky')],
#            'beg': [(159, 'Pyotr Petrovitch')],
#            'began': [(131, 'Raskolnikov'),
#                      (161, 'Raskolnikov'),
#                      (249, 'Sonia'),
#                      (217, 'Razumihin'),
#                      (213, 'Porfiry'),
#                      (153, 'Rodya'),
#                      (164, 'Avdotya Romanovna'),
#                      (138, 'Katerina Ivanovna'),
#                      (159, 'Pyotr Petrovitch'),
#                      (285, 'Svidrigaïlov'),
#                      (216, 'Nikolay'),
#                      (181, 'Koch'),
#                      (151, 'Nastasya'),
#                      (225, 'Lebeziatnikov'),
#                      (132, 'Lizaveta'),
#                      (111, 'Dostoevsky'),
#                      (176, 'Mikolka'),
#                      (221, 'CHAPTER V This')],
#            'begged': [(189, 'Karl')],
#            'begin': [(138, 'Katerina Ivanovna')],
#            'beginning': [(191, 'Nikodim Fomitch')],
#            'begun': [(111, 'Dostoevsky')],
#            'behaved': [(295, 'Philip')],
#            'believe': [(131, 'Raskolnikov'),
#                        (213, 'Porfiry'),
#                        (154, 'Dounia'),
#                        (156, 'Svidrigaïlov'),
#                        (153, 'Rodya'),
#                        (285, 'Svidrigaïlov'),
#                        (207, 'Zametov'),
#                        (166, 'Mother')],
#            'believed': [(136, 'Sofya Semyonovna'), (301, 'Jesus')],
#            'bid': [(111, 'Dostoevsky')],
#            'bless': [(134, 'God')],
#            'bought': [(157, 'Marfa Petrovna')],
#            'broke': [(134, 'God')],
#            'brought': [(207, 'Zametov'),
#                        (151, 'Nastasya'),
#                        (295, 'Philip'),
#                        (278, 'Napoleon'),
#                        (311, 'The Pole')],
#            'burst': [(331, 'Parasha')],
#            'butchered': [(176, 'Mikolka')],
#            'call': [(334, 'Raskolnikov'), (246, 'Amalia Ludwigovna')],
#            'came': [(249, 'Sonia'),
#                     (164, 'Avdotya Romanovna'),
#                     (173, 'Razumihin'),
#                     (285, 'Svidrigaïlov'),
#                     (216, 'Nikolay'),
#                     (201, 'Zossimov'),
#                     (151, 'Nastasya'),
#                     (157, 'Marfa Petrovna'),
#                     (239, 'Polenka'),
#                     (139, 'Sonia'),
#                     (301, 'Jesus'),
#                     (166, 'Mother'),
#                     (189, 'Karl'),
#                     (188, 'Mr. Captain'),
#                     (331, 'Parasha')],
#            'care': [(173, 'Razumihin')],
#            'catch': [(207, 'Zametov')],
#            'cheat': [(215, 'Dushkin')],
#            'cherishing': [(199, 'Pashenka')],
#            'clasped': [(189, 'Karl')],
#            'come': [(131, 'Raskolnikov'),
#                     (161, 'Raskolnikov'),
#                     (249, 'Sonia'),
#                     (217, 'Razumihin'),
#                     (213, 'Porfiry'),
#                     (154, 'Dounia'),
#                     (156, 'Svidrigaïlov'),
#                     (153, 'Rodya'),
#                     (164, 'Avdotya Romanovna'),
#                     (173, 'Razumihin'),
#                     (159, 'Pyotr Petrovitch'),
#                     (216, 'Nikolay'),
#                     (201, 'Zossimov'),
#                     (207, 'Zametov'),
#                     (181, 'Koch'),
#                     (137, 'Lebeziatnikov'),
#                     (136, 'Sofya Semyonovna'),
#                     (132, 'Lizaveta'),
#                     (239, 'Polenka'),
#                     (187, 'Ilya Petrovitch'),
#                     (334, 'Raskolnikov'),
#                     (301, 'Jesus'),
#                     (245, 'Lida'),
#                     (240, 'Papa'),
#                     (263, 'Brother'),
#                     (221, 'CHAPTER V This'),
#                     (279, 'Lazarus'),
#                     (331, 'Parasha'),
#                     (243, 'Prince Schegolskoy'),
#                     (350, 'Easter')],
#            'comes': [(139, 'Sonia')],
#            'comforts': [(139, 'Sonia')],
#            'coming': [(301, 'Jesus'), (192, 'Pestryakov')],
#            'concluded': [(187, 'Ilya Petrovitch'), (111, 'Dostoevsky')],
#            'continued': [(191, 'Nikodim Fomitch')],
#            'contrived': [(111, 'Dostoevsky')],
#            'corrected': [(266, 'Sofya Ivanovna')],
#            'cried': [(161, 'Raskolnikov'),
#                      (249, 'Sonia'),
#                      (217, 'Razumihin'),
#                      (213, 'Porfiry'),
#                      (154, 'Dounia'),
#                      (138, 'Katerina Ivanovna'),
#                      (173, 'Razumihin'),
#                      (181, 'Koch'),
#                      (151, 'Nastasya'),
#                      (225, 'Lebeziatnikov'),
#                      (239, 'Polenka'),
#                      (134, 'God'),
#                      (187, 'Ilya Petrovitch'),
#                      (267, 'Raskolnikov'),
#                      (301, 'Jesus'),
#                      (176, 'Mikolka'),
#                      (339, 'Achilles')],
#            'crossing': [(166, 'Mother'), (240, 'Papa')],
#            'curtsied': [(183, 'Luise Ivanovna')],
#            'cut': [(181, 'Koch')],
#            'cutting': [(263, 'Brother')],
#            'dance': [(251, 'Kolya')],
#            'danced': [(243, 'Prince Schegolskoy')],
#            'dare': [(132, 'Lizaveta'), (246, 'Amalia Ludwigovna')],
#            'daresay': [(191, 'Nikodim Fomitch')],
#            'darn': [(240, 'Papa')],
#            'decide': [(136, 'Sofya Semyonovna')],
#            'declared': [(136, 'Sofya Semyonovna')],
#            'delivered': [(134, 'God')],
#            'describes': [(111, 'Dostoevsky')],
#            'developing': [(225, 'Lebeziatnikov')],
#            'devoted': [(306, 'Terebyeva')],
#            'did': [(137, 'Lebeziatnikov'), (132, 'Lizaveta')],
#            'die': [(138, 'Katerina Ivanovna'), (147, 'Semyon Zaharovitch')],
#            'died': [(157, 'Marfa Petrovna'), (111, 'Dostoevsky')],
#            'dislike': [(246, 'Amalia Ludwigovna')],
#            'disliked': [(247, 'Amalia Ivanovna')],
#            'distributed': [(354, 'Hart')],
#            'do': [(156, 'Svidrigaïlov'),
#                   (207, 'Zametov'),
#                   (134, 'God'),
#                   (166, 'Mother'),
#                   (176, 'Mikolka')],
#            'does': [(207, 'Zametov'), (210, 'Tolstyakov')],
#            'doing': [(207, 'Zametov'), (247, 'Amalia Ivanovna')],
#            'done': [(163, 'Luzhin'),
#                     (157, 'Marfa Petrovna'),
#                     (247, 'Amalia Ivanovna'),
#                     (240, 'Papa'),
#                     (278, 'Napoleon')],
#            'drank': [(329, 'Katia')],
#            'drawled': [(187, 'Ilya Petrovitch')],
#            'drove': [(139, 'Sonia')],
#            'dying': [(147, 'Semyon Zaharovitch')],
#            'earned': [(132, 'Lizaveta')],
#            'embraced': [(157, 'Marfa Petrovna')],
#            'employed': [(132, 'Lizaveta')],
#            'end': [(295, 'Philip')],
#            'entering': [(306, 'Terebyeva')],
#            'esteems': [(257, 'Luzhin')],
#            'expand': [(194, 'Heruvimov')],
#            'expect': [(216, 'Nikolay')],
#            'explain': [(191, 'Nikodim Fomitch')],
#            'feeling': [(346, 'Hulloa')],
#            'feels': [(247, 'Amalia Ivanovna')],
#            'fell': [(176, 'Mikolka'), (183, 'Luise Ivanovna'), (300, 'Mary')],
#            'felt': [(131, 'Raskolnikov'),
#                     (161, 'Raskolnikov'),
#                     (249, 'Sonia'),
#                     (164, 'Avdotya Romanovna'),
#                     (173, 'Razumihin'),
#                     (285, 'Svidrigaïlov'),
#                     (151, 'Nastasya'),
#                     (278, 'Napoleon')],
#            'fidget': [(251, 'Kolya')],
#            'find': [(159, 'Pyotr Petrovitch'), (239, 'Polenka')],
#            'flew': [(176, 'Mikolka')],
#            'fluttered': [(183, 'Luise Ivanovna')],
#            'forbid': [(134, 'God')],
#            'forced': [(239, 'Polenka')],
#            'forgive': [(134, 'God')],
#            'forgot': [(216, 'Nikolay')],
#            'found': [(173, 'Razumihin'), (159, 'Pyotr Petrovitch')],
#            'fuming': [(183, 'Luise Ivanovna')],
#            'gave': [(249, 'Sonia'),
#                     (164, 'Avdotya Romanovna'),
#                     (159, 'Pyotr Petrovitch'),
#                     (207, 'Zametov'),
#                     (157, 'Marfa Petrovna'),
#                     (137, 'Lebeziatnikov'),
#                     (132, 'Lizaveta'),
#                     (139, 'Sonia'),
#                     (199, 'Pashenka'),
#                     (133, 'Alyona Ivanovna')],
#            'get': [(156, 'Svidrigaïlov'),
#                    (225, 'Lebeziatnikov'),
#                    (132, 'Lizaveta'),
#                    (139, 'Sonia'),
#                    (134, 'God'),
#                    (199, 'Pashenka'),
#                    (268, 'Madame Resslich'),
#                    (183, 'Luise Ivanovna'),
#                    (221, 'CHAPTER V This')],
#            'give': [(213, 'Porfiry'),
#                     (134, 'God'),
#                     (199, 'Pashenka'),
#                     (133, 'Alyona Ivanovna')],
#            'given': [(153, 'Rodya'),
#                      (216, 'Nikolay'),
#                      (136, 'Sofya Semyonovna')],
#            'gives': [(139, 'Sonia'), (327, 'Dr. B----n')],
#            'glancing': [(191, 'Nikodim Fomitch')],
#            'go': [(161, 'Raskolnikov'),
#                   (217, 'Razumihin'),
#                   (156, 'Svidrigaïlov'),
#                   (153, 'Rodya'),
#                   (216, 'Nikolay'),
#                   (201, 'Zossimov'),
#                   (207, 'Zametov'),
#                   (181, 'Koch'),
#                   (163, 'Luzhin'),
#                   (239, 'Polenka'),
#                   (301, 'Jesus'),
#                   (306, 'Terebyeva')],
#            'goes': [(210, 'Tolstyakov')],
#            'going': [(153, 'Rodya'),
#                      (285, 'Svidrigaïlov'),
#                      (181, 'Koch'),
#                      (163, 'Luzhin'),
#                      (134, 'God'),
#                      (334, 'Raskolnikov'),
#                      (267, 'Raskolnikov'),
#                      (192, 'Pestryakov'),
#                      (194, 'Heruvimov'),
#                      (287, 'Berg')],
#            'gone': [(216, 'Nikolay'),
#                     (187, 'Ilya Petrovitch'),
#                     (145, 'Kapernaumov')],
#            'got': [(249, 'Sonia'),
#                    (217, 'Razumihin'),
#                    (285, 'Svidrigaïlov'),
#                    (216, 'Nikolay'),
#                    (201, 'Zossimov'),
#                    (163, 'Luzhin'),
#                    (157, 'Marfa Petrovna'),
#                    (239, 'Polenka'),
#                    (139, 'Sonia'),
#                    (147, 'Semyon Zaharovitch'),
#                    (268, 'Madame Resslich')],
#            'grant': [(134, 'God')],
#            'gratified': [(187, 'Ilya Petrovitch')],
#            'groaned': [(301, 'Jesus')],
#            'groaning': [(301, 'Jesus')],
#            'grudged': [(268, 'Madame Resslich')],
#            'had': [(131, 'Raskolnikov'),
#                    (161, 'Raskolnikov'),
#                    (249, 'Sonia'),
#                    (217, 'Razumihin'),
#                    (213, 'Porfiry'),
#                    (154, 'Dounia'),
#                    (156, 'Svidrigaïlov'),
#                    (153, 'Rodya'),
#                    (138, 'Katerina Ivanovna'),
#                    (173, 'Razumihin'),
#                    (159, 'Pyotr Petrovitch'),
#                    (285, 'Svidrigaïlov'),
#                    (216, 'Nikolay'),
#                    (207, 'Zametov'),
#                    (157, 'Marfa Petrovna'),
#                    (137, 'Lebeziatnikov'),
#                    (136, 'Sofya Semyonovna'),
#                    (247, 'Amalia Ivanovna'),
#                    (139, 'Sonia'),
#                    (111, 'Dostoevsky'),
#                    (267, 'Raskolnikov'),
#                    (133, 'Alyona Ivanovna'),
#                    (147, 'Semyon Zaharovitch'),
#                    (245, 'Lida'),
#                    (278, 'Napoleon'),
#                    (152, 'Praskovya Pavlovna'),
#                    (274, 'Newton'),
#                    (342, 'Lizaveta’s')],
#            'hanged': [(295, 'Philip')],
#            'happened': [(278, 'Napoleon')],
#            'has': [(154, 'Dounia'),
#                    (153, 'Rodya'),
#                    (138, 'Katerina Ivanovna'),
#                    (163, 'Luzhin'),
#                    (136, 'Sofya Semyonovna'),
#                    (139, 'Sonia'),
#                    (199, 'Pashenka'),
#                    (268, 'Madame Resslich')],
#            'hated': [(268, 'Madame Resslich')],
#            'have': [(131, 'Raskolnikov'),
#                     (161, 'Raskolnikov'),
#                     (217, 'Razumihin'),
#                     (213, 'Porfiry'),
#                     (154, 'Dounia'),
#                     (156, 'Svidrigaïlov'),
#                     (153, 'Rodya'),
#                     (164, 'Avdotya Romanovna'),
#                     (173, 'Razumihin'),
#                     (216, 'Nikolay'),
#                     (207, 'Zametov'),
#                     (181, 'Koch'),
#                     (151, 'Nastasya'),
#                     (163, 'Luzhin'),
#                     (225, 'Lebeziatnikov'),
#                     (247, 'Amalia Ivanovna'),
#                     (134, 'God'),
#                     (297, 'the Kapernaumovs')],
#            'hear': [(216, 'Nikolay'),
#                     (166, 'Mother'),
#                     (183, 'Luise Ivanovna'),
#                     (144, 'Amalia Fyodorovna')],
#            'heard': [(131, 'Raskolnikov'),
#                      (213, 'Porfiry'),
#                      (153, 'Rodya'),
#                      (138, 'Katerina Ivanovna'),
#                      (285, 'Svidrigaïlov'),
#                      (181, 'Koch'),
#                      (137, 'Lebeziatnikov'),
#                      (191, 'Nikodim Fomitch'),
#                      (299, 'Martha')],
#            'held': [(137, 'Lebeziatnikov')],
#            'hit': [(189, 'Karl')],
#            'hope': [(163, 'Luzhin')],
#            'ilya': [(191, 'Nikodim Fomitch')],
#            'imagine': [(225, 'Lebeziatnikov')],
#            'insists': [(111, 'Dostoevsky')],
#            'interposed': [(187, 'Ilya Petrovitch')],
#            'interrupted': [(187, 'Ilya Petrovitch')],
#            'jumped': [(181, 'Koch')],
#            'keep': [(239, 'Polenka'), (251, 'Kolya')],
#            'keeps': [(133, 'Alyona Ivanovna')],
#            'kept': [(157, 'Marfa Petrovna'),
#                     (137, 'Lebeziatnikov'),
#                     (133, 'Alyona Ivanovna')],
#            'kicking': [(187, 'Ilya Petrovitch')],
#            'kill': [(216, 'Nikolay'), (176, 'Mikolka'), (189, 'Karl')],
#            'killed': [(133, 'Alyona Ivanovna')],
#            'knelt': [(157, 'Marfa Petrovna')],
#            'knew': [(249, 'Sonia'),
#                     (173, 'Razumihin'),
#                     (181, 'Koch'),
#                     (132, 'Lizaveta'),
#                     (247, 'Amalia Ivanovna'),
#                     (187, 'Ilya Petrovitch'),
#                     (191, 'Nikodim Fomitch')],
#            'knocked': [(192, 'Pestryakov')],
#            'know': [(131, 'Raskolnikov'),
#                     (161, 'Raskolnikov'),
#                     (249, 'Sonia'),
#                     (217, 'Razumihin'),
#                     (213, 'Porfiry'),
#                     (154, 'Dounia'),
#                     (156, 'Svidrigaïlov'),
#                     (153, 'Rodya'),
#                     (164, 'Avdotya Romanovna'),
#                     (173, 'Razumihin'),
#                     (285, 'Svidrigaïlov'),
#                     (216, 'Nikolay'),
#                     (201, 'Zossimov'),
#                     (207, 'Zametov'),
#                     (151, 'Nastasya'),
#                     (163, 'Luzhin'),
#                     (225, 'Lebeziatnikov'),
#                     (247, 'Amalia Ivanovna'),
#                     (239, 'Polenka'),
#                     (267, 'Raskolnikov'),
#                     (191, 'Nikodim Fomitch'),
#                     (133, 'Alyona Ivanovna'),
#                     (166, 'Mother'),
#                     (330, 'Schiller')],
#            'known': [(207, 'Zametov'), (147, 'Semyon Zaharovitch')],
#            'knows': [(134, 'God'), (245, 'Lida'), (160, 'Afanasy Ivanovitch')],
#            'laid': [(139, 'Sonia'), (267, 'Raskolnikov'), (300, 'Mary')],
#            'laughed': [(267, 'Raskolnikov'), (327, 'Dr. B----n')],
#            'lay': [(240, 'Papa')],
#            'learnt': [(334, 'Raskolnikov')],
#            'leaves': [(145, 'Kapernaumov')],
#            'left': [(151, 'Nastasya'),
#                     (157, 'Marfa Petrovna'),
#                     (132, 'Lizaveta'),
#                     (247, 'Amalia Ivanovna'),
#                     (306, 'Terebyeva'),
#                     (274, 'Newton'),
#                     (346, 'Hulloa')],
#            'let': [(213, 'Porfiry'),
#                    (201, 'Zossimov'),
#                    (163, 'Luzhin'),
#                    (134, 'God'),
#                    (297, 'the Kapernaumovs')],
#            'lets': [(134, 'God')],
#            'lies': [(215, 'Dushkin')],
#            'lifted': [(132, 'Lizaveta'), (301, 'Jesus')],
#            'like': [(156, 'Svidrigaïlov'),
#                     (173, 'Razumihin'),
#                     (207, 'Zametov'),
#                     (225, 'Lebeziatnikov'),
#                     (334, 'Raskolnikov'),
#                     (166, 'Mother'),
#                     (335, 'Scoundrel')],
#            'liking': [(152, 'Praskovya Pavlovna')],
#            'listened': [(136, 'Sofya Semyonovna')],
#            'live': [(267, 'Raskolnikov'), (297, 'the Kapernaumovs')],
#            'lived': [(267, 'Raskolnikov')],
#            'lives': [(268, 'Madame Resslich')],
#            'lock': [(334, 'Raskolnikov')],
#            'locked': [(152, 'Praskovya Pavlovna')],
#            'look': [(173, 'Razumihin'), (183, 'Luise Ivanovna')],
#            'looked': [(131, 'Raskolnikov'),
#                       (161, 'Raskolnikov'),
#                       (249, 'Sonia'),
#                       (213, 'Porfiry'),
#                       (154, 'Dounia'),
#                       (156, 'Svidrigaïlov'),
#                       (164, 'Avdotya Romanovna'),
#                       (138, 'Katerina Ivanovna'),
#                       (173, 'Razumihin'),
#                       (159, 'Pyotr Petrovitch'),
#                       (285, 'Svidrigaïlov'),
#                       (207, 'Zametov'),
#                       (151, 'Nastasya'),
#                       (239, 'Polenka'),
#                       (139, 'Sonia'),
#                       (191, 'Nikodim Fomitch')],
#            'looking': [(187, 'Ilya Petrovitch')],
#            'lost': [(181, 'Koch'), (111, 'Dostoevsky')],
#            'love': [(239, 'Polenka'), (166, 'Mother')],
#            'loved': [(301, 'Jesus')],
#            'loves': [(154, 'Dounia'), (199, 'Pashenka')],
#            'made': [(131, 'Raskolnikov'),
#                     (156, 'Svidrigaïlov'),
#                     (153, 'Rodya'),
#                     (164, 'Avdotya Romanovna'),
#                     (159, 'Pyotr Petrovitch'),
#                     (201, 'Zossimov'),
#                     (163, 'Luzhin'),
#                     (139, 'Sonia'),
#                     (111, 'Dostoevsky'),
#                     (199, 'Pashenka'),
#                     (191, 'Nikodim Fomitch'),
#                     (183, 'Luise Ivanovna'),
#                     (152, 'Praskovya Pavlovna'),
#                     (257, 'Luzhin'),
#                     (186, 'Tchebarov')],
#            'maintained': [(187, 'Ilya Petrovitch')],
#            'make': [(136, 'Sofya Semyonovna'),
#                     (132, 'Lizaveta'),
#                     (245, 'Lida'),
#                     (268, 'Madame Resslich'),
#                     (251, 'Kolya'),
#                     (288, 'Aniska')],
#            'making': [(247, 'Amalia Ivanovna')],
#            'manage': [(240, 'Papa')],
#            'mean': [(225, 'Lebeziatnikov'),
#                     (137, 'Lebeziatnikov'),
#                     (267, 'Raskolnikov'),
#                     (287, 'Berg')],
#            'means': [(152, 'Praskovya Pavlovna')],
#            'meant': [(247, 'Amalia Ivanovna'), (267, 'Raskolnikov')],
#            'mend': [(240, 'Papa')],
#            'mentioning': [(267, 'Raskolnikov')],
#            'met': [(247, 'Amalia Ivanovna'), (239, 'Polenka')],
#            'muttered': [(191, 'Nikodim Fomitch')],
#            'need': [(166, 'Mother'), (263, 'Brother')],
#            'notice': [(216, 'Nikolay'), (192, 'Pestryakov')],
#            'noticed': [(181, 'Koch')],
#            'observe': [(335, 'Scoundrel')],
#            'observed': [(201, 'Zossimov'),
#                         (334, 'Raskolnikov'),
#                         (191, 'Nikodim Fomitch')],
#            'offer': [(163, 'Luzhin')],
#            'opened': [(181, 'Koch')],
#            'overheard': [(157, 'Marfa Petrovna')],
#            'paid': [(225, 'Lebeziatnikov')],
#            'pass': [(159, 'Pyotr Petrovitch')],
#            'passed': [(181, 'Koch')],
#            'patronising': [(247, 'Amalia Ivanovna')],
#            'pattered': [(188, 'Mr. Captain')],
#            'paused': [(159, 'Pyotr Petrovitch')],
#            'pays': [(194, 'Heruvimov')],
#            'perceived': [(267, 'Raskolnikov')],
#            'pestered': [(225, 'Lebeziatnikov')],
#            'pierced': [(189, 'Karl')],
#            'planned': [(199, 'Pashenka')],
#            'pledged': [(267, 'Raskolnikov')],
#            'pointed': [(257, 'Luzhin')],
#            'pondering': [(132, 'Lizaveta')],
#            'presented': [(186, 'Tchebarov')],
#            'produced': [(354, 'Hart')],
#            'promise': [(147, 'Semyon Zaharovitch')],
#            'pronounced': [(187, 'Ilya Petrovitch')],
#            'protect': [(134, 'God')],
#            'proved': [(347, 'Dr. Zossimov')],
#            'published': [(116, 'the poet Nekrassov')],
#            'pulled': [(189, 'Karl')],
#            'pushed': [(193, 'Good Lord')],
#            'put': [(154, 'Dounia'),
#                    (138, 'Katerina Ivanovna'),
#                    (159, 'Pyotr Petrovitch'),
#                    (285, 'Svidrigaïlov'),
#                    (137, 'Lebeziatnikov'),
#                    (247, 'Amalia Ivanovna'),
#                    (334, 'Raskolnikov'),
#                    (267, 'Raskolnikov')],
#            'puts': [(163, 'Luzhin')],
#            'raised': [(339, 'Achilles')],
#            'ran': [(138, 'Katerina Ivanovna'),
#                    (216, 'Nikolay'),
#                    (145, 'Kapernaumov')],
#            'read': [(139, 'Sonia'), (295, 'Philip'), (299, 'Martha')],
#            'reading': [(157, 'Marfa Petrovna')],
#            'received': [(111, 'Dostoevsky'),
#                         (295, 'Philip'),
#                         (203, 'Semyon Semyonovitch')],
#            'recollected': [(181, 'Koch')],
#            'recurs': [(111, 'Dostoevsky')],
#            'refrained': [(334, 'Raskolnikov')],
#            'refuse': [(160, 'Afanasy Ivanovitch')],
#            'refused': [(157, 'Marfa Petrovna')],
#            'regarded': [(136, 'Sofya Semyonovna')],
#            'rejoice': [(163, 'Luzhin')],
#            'released': [(191, 'Nikodim Fomitch')],
#            'remained': [(136, 'Sofya Semyonovna')],
#            'remember': [(207, 'Zametov'), (263, 'Brother')],
#            'remembered': [(181, 'Koch')],
#            'repeated': [(137, 'Lebeziatnikov'), (191, 'Nikodim Fomitch')],
#            'replied': [(159, 'Pyotr Petrovitch')],
#            'reproached': [(157, 'Marfa Petrovna')],
#            'respected': [(247, 'Amalia Ivanovna')],
#            'rest': [(134, 'God')],
#            'resting': [(147, 'Semyon Zaharovitch')],
#            'restrain': [(267, 'Raskolnikov')],
#            'retired': [(187, 'Ilya Petrovitch')],
#            'returned': [(151, 'Nastasya')],
#            'run': [(239, 'Polenka'), (240, 'Papa')],
#            'running': [(239, 'Polenka')],
#            'rushed': [(138, 'Katerina Ivanovna')],
#            'said': [(131, 'Raskolnikov'),
#                     (161, 'Raskolnikov'),
#                     (249, 'Sonia'),
#                     (217, 'Razumihin'),
#                     (213, 'Porfiry'),
#                     (154, 'Dounia'),
#                     (156, 'Svidrigaïlov'),
#                     (153, 'Rodya'),
#                     (164, 'Avdotya Romanovna'),
#                     (138, 'Katerina Ivanovna'),
#                     (173, 'Razumihin'),
#                     (159, 'Pyotr Petrovitch'),
#                     (285, 'Svidrigaïlov'),
#                     (216, 'Nikolay'),
#                     (201, 'Zossimov'),
#                     (207, 'Zametov'),
#                     (151, 'Nastasya'),
#                     (163, 'Luzhin'),
#                     (157, 'Marfa Petrovna'),
#                     (137, 'Lebeziatnikov'),
#                     (132, 'Lizaveta'),
#                     (139, 'Sonia'),
#                     (334, 'Raskolnikov'),
#                     (301, 'Jesus'),
#                     (245, 'Lida'),
#                     (268, 'Madame Resslich'),
#                     (240, 'Papa'),
#                     (299, 'Martha'),
#                     (306, 'Terebyeva'),
#                     (327, 'Dr. B----n')],
#            'saith': [(299, 'Martha')],
#            'sang': [(329, 'Katia')],
#            'sat': [(249, 'Sonia'),
#                    (156, 'Svidrigaïlov'),
#                    (285, 'Svidrigaïlov'),
#                    (181, 'Koch'),
#                    (300, 'Mary')],
#            'saw': [(161, 'Raskolnikov'),
#                    (154, 'Dounia'),
#                    (156, 'Svidrigaïlov'),
#                    (159, 'Pyotr Petrovitch'),
#                    (285, 'Svidrigaïlov'),
#                    (201, 'Zossimov'),
#                    (225, 'Lebeziatnikov'),
#                    (137, 'Lebeziatnikov'),
#                    (301, 'Jesus'),
#                    (329, 'Katia')],
#            'say': [(213, 'Porfiry'),
#                    (164, 'Avdotya Romanovna'),
#                    (285, 'Svidrigaïlov'),
#                    (201, 'Zossimov'),
#                    (187, 'Ilya Petrovitch'),
#                    (245, 'Lida'),
#                    (251, 'Kolya'),
#                    (339, 'Achilles')],
#            'saying': [(132, 'Lizaveta'), (246, 'Amalia Ludwigovna')],
#            'says': [(111, 'Dostoevsky'),
#                     (199, 'Pashenka'),
#                     (147, 'Semyon Zaharovitch')],
#            'scanned': [(221, 'CHAPTER V This')],
#            'scared': [(251, 'Kolya')],
#            'scrawl': [(160, 'Afanasy Ivanovitch')],
#            'screamed': [(176, 'Mikolka'), (245, 'Lida')],
#            'scrutinised': [(221, 'CHAPTER V This')],
#            'see': [(161, 'Raskolnikov'),
#                    (249, 'Sonia'),
#                    (217, 'Razumihin'),
#                    (213, 'Porfiry'),
#                    (154, 'Dounia'),
#                    (156, 'Svidrigaïlov'),
#                    (153, 'Rodya'),
#                    (164, 'Avdotya Romanovna'),
#                    (138, 'Katerina Ivanovna'),
#                    (173, 'Razumihin'),
#                    (216, 'Nikolay'),
#                    (201, 'Zossimov'),
#                    (239, 'Polenka'),
#                    (334, 'Raskolnikov'),
#                    (267, 'Raskolnikov'),
#                    (166, 'Mother'),
#                    (246, 'Amalia Ludwigovna')],
#            'seem': [(163, 'Luzhin')],
#            'seemed': [(138, 'Katerina Ivanovna'), (163, 'Luzhin')],
#            'seen': [(161, 'Raskolnikov'), (278, 'Napoleon')],
#            'seized': [(251, 'Kolya')],
#            'sent': [(159, 'Pyotr Petrovitch'),
#                     (134, 'God'),
#                     (160, 'Afanasy Ivanovitch'),
#                     (282, 'Providence')],
#            'set': [(151, 'Nastasya')],
#            'shaved': [(152, 'Praskovya Pavlovna')],
#            'shouted': [(138, 'Katerina Ivanovna'),
#                        (173, 'Razumihin'),
#                        (176, 'Mikolka'),
#                        (295, 'Philip')],
#            'show': [(176, 'Mikolka')],
#            'showed': [(201, 'Zossimov')],
#            'shown': [(136, 'Sofya Semyonovna'), (111, 'Dostoevsky')],
#            'sign': [(160, 'Afanasy Ivanovitch')],
#            'sing': [(239, 'Polenka')],
#            'sings': [(245, 'Lida')],
#            'sit': [(251, 'Kolya')],
#            'slipped': [(137, 'Lebeziatnikov')],
#            'sounded': [(327, 'Dr. B----n')],
#            'spared': [(306, 'Terebyeva')],
#            'speak': [(191, 'Nikodim Fomitch')],
#            'speaking': [(139, 'Sonia')],
#            'spoke': [(132, 'Lizaveta')],
#            'spoken': [(136, 'Sofya Semyonovna'), (301, 'Jesus')],
#            'standing': [(159, 'Pyotr Petrovitch'),
#                         (151, 'Nastasya'),
#                         (132, 'Lizaveta'),
#                         (191, 'Nikodim Fomitch')],
#            'stared': [(201, 'Zossimov'), (221, 'CHAPTER V This')],
#            'started': [(111, 'Dostoevsky')],
#            'stinketh': [(301, 'Jesus')],
#            'stood': [(131, 'Raskolnikov'),
#                      (161, 'Raskolnikov'),
#                      (249, 'Sonia'),
#                      (154, 'Dounia'),
#                      (138, 'Katerina Ivanovna'),
#                      (151, 'Nastasya'),
#                      (137, 'Lebeziatnikov'),
#                      (176, 'Mikolka')],
#            'stopped': [(139, 'Sonia'),
#                        (187, 'Ilya Petrovitch'),
#                        (267, 'Raskolnikov'),
#                        (176, 'Mikolka')],
#            'strangled': [(278, 'Napoleon')],
#            'struck': [(136, 'Sofya Semyonovna')],
#            'stumbled': [(183, 'Luise Ivanovna')],
#            'succeeded': [(193, 'Good Lord')],
#            'suffered': [(111, 'Dostoevsky')],
#            'suppose': [(136, 'Sofya Semyonovna')],
#            'surrendered': [(304, 'General Mack')],
#            'swung': [(176, 'Mikolka')],
#            'take': [(207, 'Zametov'),
#                     (151, 'Nastasya'),
#                     (137, 'Lebeziatnikov'),
#                     (239, 'Polenka'),
#                     (334, 'Raskolnikov'),
#                     (176, 'Mikolka'),
#                     (240, 'Papa'),
#                     (287, 'Berg')],
#            'taken': [(159, 'Pyotr Petrovitch')],
#            'talking': [(217, 'Razumihin'), (191, 'Nikodim Fomitch')],
#            'teach': [(176, 'Mikolka')],
#            'tell': [(131, 'Raskolnikov'),
#                     (217, 'Razumihin'),
#                     (154, 'Dounia'),
#                     (156, 'Svidrigaïlov'),
#                     (164, 'Avdotya Romanovna'),
#                     (159, 'Pyotr Petrovitch'),
#                     (201, 'Zossimov'),
#                     (151, 'Nastasya'),
#                     (225, 'Lebeziatnikov'),
#                     (134, 'God')],
#            'thanked': [(243, 'Prince Schegolskoy')],
#            'think': [(131, 'Raskolnikov'),
#                      (213, 'Porfiry'),
#                      (154, 'Dounia'),
#                      (156, 'Svidrigaïlov'),
#                      (153, 'Rodya'),
#                      (201, 'Zossimov'),
#                      (151, 'Nastasya'),
#                      (163, 'Luzhin'),
#                      (225, 'Lebeziatnikov')],
#            'thinks': [(268, 'Madame Resslich'), (257, 'Luzhin')],
#            'thought': [(131, 'Raskolnikov'),
#                        (161, 'Raskolnikov'),
#                        (217, 'Razumihin'),
#                        (213, 'Porfiry'),
#                        (164, 'Avdotya Romanovna'),
#                        (285, 'Svidrigaïlov'),
#                        (181, 'Koch'),
#                        (137, 'Lebeziatnikov'),
#                        (111, 'Dostoevsky'),
#                        (267, 'Raskolnikov'),
#                        (199, 'Pashenka'),
#                        (166, 'Mother')],
#            'thrashed': [(176, 'Mikolka')],
#            'throw': [(163, 'Luzhin')],
#            'thrown': [(247, 'Amalia Ivanovna')],
#            'told': [(217, 'Razumihin'),
#                     (156, 'Svidrigaïlov'),
#                     (164, 'Avdotya Romanovna'),
#                     (138, 'Katerina Ivanovna'),
#                     (173, 'Razumihin'),
#                     (157, 'Marfa Petrovna'),
#                     (268, 'Madame Resslich'),
#                     (307, 'Varents')],
#            'took': [(217, 'Razumihin'),
#                     (213, 'Porfiry'),
#                     (154, 'Dounia'),
#                     (138, 'Katerina Ivanovna'),
#                     (285, 'Svidrigaïlov'),
#                     (239, 'Polenka'),
#                     (187, 'Ilya Petrovitch'),
#                     (111, 'Dostoevsky'),
#                     (199, 'Pashenka'),
#                     (133, 'Alyona Ivanovna'),
#                     (189, 'Karl'),
#                     (329, 'Katia'),
#                     (143, 'Darya Frantsovna')],
#            'tore': [(189, 'Karl')],
#            'torn': [(240, 'Papa')],
#            'treated': [(247, 'Amalia Ivanovna')],
#            'tried': [(186, 'Tchebarov')],
#            'trust': [(199, 'Pashenka'), (160, 'Afanasy Ivanovitch')],
#            'trusts': [(199, 'Pashenka')],
#            'try': [(263, 'Brother')],
#            'turned': [(131, 'Raskolnikov'),
#                       (161, 'Raskolnikov'),
#                       (249, 'Sonia'),
#                       (217, 'Razumihin'),
#                       (213, 'Porfiry'),
#                       (164, 'Avdotya Romanovna'),
#                       (285, 'Svidrigaïlov'),
#                       (181, 'Koch'),
#                       (136, 'Sofya Semyonovna'),
#                       (334, 'Raskolnikov'),
#                       (329, 'Katia')],
#            'turns': [(186, 'Tchebarov')],
#            'understand': [(161, 'Raskolnikov'),
#                           (249, 'Sonia'),
#                           (217, 'Razumihin'),
#                           (164, 'Avdotya Romanovna'),
#                           (138, 'Katerina Ivanovna'),
#                           (216, 'Nikolay'),
#                           (225, 'Lebeziatnikov'),
#                           (137, 'Lebeziatnikov'),
#                           (136, 'Sofya Semyonovna'),
#                           (187, 'Ilya Petrovitch'),
#                           (334, 'Raskolnikov'),
#                           (245, 'Lida'),
#                           (251, 'Kolya')],
#            'understands': [(136, 'Sofya Semyonovna')],
#            'undertaken': [(247, 'Amalia Ivanovna')],
#            'undertook': [(132, 'Lizaveta')],
#            'undressing': [(239, 'Polenka')],
#            'used': [(138, 'Katerina Ivanovna'),
#                     (157, 'Marfa Petrovna'),
#                     (132, 'Lizaveta'),
#                     (268, 'Madame Resslich')],
#            'uttering': [(187, 'Ilya Petrovitch')],
#            'wailed': [(331, 'Parasha')],
#            'waiting': [(160, 'Afanasy Ivanovitch')],
#            'walked': [(131, 'Raskolnikov'),
#                       (285, 'Svidrigaïlov'),
#                       (137, 'Lebeziatnikov'),
#                       (139, 'Sonia'),
#                       (187, 'Ilya Petrovitch'),
#                       (334, 'Raskolnikov')],
#            'want': [(131, 'Raskolnikov'),
#                     (217, 'Razumihin'),
#                     (213, 'Porfiry'),
#                     (154, 'Dounia'),
#                     (156, 'Svidrigaïlov'),
#                     (164, 'Avdotya Romanovna'),
#                     (173, 'Razumihin'),
#                     (201, 'Zossimov'),
#                     (151, 'Nastasya'),
#                     (163, 'Luzhin'),
#                     (225, 'Lebeziatnikov'),
#                     (239, 'Polenka')],
#            'wanted': [(153, 'Rodya'),
#                       (207, 'Zametov'),
#                       (225, 'Lebeziatnikov'),
#                       (137, 'Lebeziatnikov'),
#                       (136, 'Sofya Semyonovna'),
#                       (334, 'Raskolnikov'),
#                       (243, 'Prince Schegolskoy')],
#            'wants': [(247, 'Amalia Ivanovna')],
#            'warn': [(334, 'Raskolnikov')],
#            'was': [(331, 'Parasha')],
#            'weeping': [(301, 'Jesus')],
#            'went': [(131, 'Raskolnikov'),
#                     (161, 'Raskolnikov'),
#                     (249, 'Sonia'),
#                     (217, 'Razumihin'),
#                     (213, 'Porfiry'),
#                     (154, 'Dounia'),
#                     (153, 'Rodya'),
#                     (164, 'Avdotya Romanovna'),
#                     (173, 'Razumihin'),
#                     (159, 'Pyotr Petrovitch'),
#                     (285, 'Svidrigaïlov'),
#                     (201, 'Zossimov'),
#                     (181, 'Koch'),
#                     (151, 'Nastasya'),
#                     (157, 'Marfa Petrovna'),
#                     (136, 'Sofya Semyonovna'),
#                     (133, 'Alyona Ivanovna'),
#                     (147, 'Semyon Zaharovitch'),
#                     (266, 'Sofya Ivanovna')],
#            'wept': [(301, 'Jesus')],
#            'whispered': [(249, 'Sonia')],
#            'wished': [(334, 'Raskolnikov')],
#            'won': [(199, 'Pashenka')],
#            'wondering': [(245, 'Lida')],
#            'worked': [(132, 'Lizaveta')],
#            'working': [(216, 'Nikolay')],
#            'worn': [(240, 'Papa')],
#            'writes': [(166, 'Mother')],
#            'written': [(157, 'Marfa Petrovna'), (306, 'Terebyeva')],
#            'wrote': [(153, 'Rodya'), (163, 'Luzhin'), (306, 'Terebyeva')],
#            '’re': [(173, 'Razumihin'), (334, 'Raskolnikov')],
#            '’s': [(139, 'Sonia'), (268, 'Madame Resslich'), (278, 'Napoleon')],
#            '’ve': [(201, 'Zossimov'), (267, 'Raskolnikov')]},
#  'patient': {'abandon': [(153, 'Rodya')],
#              'abandoned': [(147, 'Semyon Zaharovitch')],
#              'accompanied': [(249, 'Sonia')],
#              'accused': [(216, 'Nikolay'), (111, 'Dostoevsky')],
#              'acquainted': [(187, 'Ilya Petrovitch')],
#              'added': [(161, 'Raskolnikov')],
#              'address': [(187, 'Ilya Petrovitch')],
#              'addressed': [(213, 'Porfiry'), (247, 'Amalia Ivanovna')],
#              'addressing': [(131, 'Raskolnikov'),
#                             (217, 'Razumihin'),
#                             (201, 'Zossimov'),
#                             (137, 'Lebeziatnikov'),
#                             (136, 'Sofya Semyonovna'),
#                             (191, 'Nikodim Fomitch')],
#              'admire': [(153, 'Rodya')],
#              'affected': [(285, 'Svidrigaïlov')],
#              'agitated': [(249, 'Sonia')],
#              'allow': [(159, 'Pyotr Petrovitch')],
#              'allowed': [(111, 'Dostoevsky')],
#              'amused': [(151, 'Nastasya')],
#              'annoy': [(173, 'Razumihin')],
#              'answered': [(213, 'Porfiry'), (285, 'Svidrigaïlov')],
#              'anticipated': [(201, 'Zossimov')],
#              'approached': [(199, 'Pashenka')],
#              'aroused': [(183, 'Luise Ivanovna')],
#              'arrest': [(131, 'Raskolnikov')],
#              'arrested': [(216, 'Nikolay'), (111, 'Dostoevsky')],
#              'ask': [(249, 'Sonia'),
#                      (217, 'Razumihin'),
#                      (213, 'Porfiry'),
#                      (153, 'Rodya'),
#                      (164, 'Avdotya Romanovna'),
#                      (173, 'Razumihin'),
#                      (216, 'Nikolay'),
#                      (201, 'Zossimov'),
#                      (139, 'Sonia'),
#                      (187, 'Ilya Petrovitch'),
#                      (145, 'Kapernaumov'),
#                      (230, 'Foo')],
#              'asked': [(131, 'Raskolnikov'),
#                        (249, 'Sonia'),
#                        (217, 'Razumihin'),
#                        (154, 'Dounia'),
#                        (153, 'Rodya'),
#                        (164, 'Avdotya Romanovna'),
#                        (173, 'Razumihin'),
#                        (159, 'Pyotr Petrovitch'),
#                        (216, 'Nikolay'),
#                        (201, 'Zossimov'),
#                        (181, 'Koch'),
#                        (151, 'Nastasya'),
#                        (225, 'Lebeziatnikov'),
#                        (137, 'Lebeziatnikov'),
#                        (136, 'Sofya Semyonovna'),
#                        (132, 'Lizaveta'),
#                        (247, 'Amalia Ivanovna'),
#                        (191, 'Nikodim Fomitch')],
#              'asking': [(164, 'Avdotya Romanovna'),
#                         (138, 'Katerina Ivanovna'),
#                         (157, 'Marfa Petrovna'),
#                         (221, 'CHAPTER V This'),
#                         (230, 'Foo')],
#              'asks': [(187, 'Ilya Petrovitch')],
#              'assure': [(131, 'Raskolnikov'),
#                         (217, 'Razumihin'),
#                         (213, 'Porfiry'),
#                         (173, 'Razumihin'),
#                         (201, 'Zossimov'),
#                         (151, 'Nastasya'),
#                         (247, 'Amalia Ivanovna'),
#                         (166, 'Mother')],
#              'assured': [(159, 'Pyotr Petrovitch'), (199, 'Pashenka')],
#              'attached': [(225, 'Lebeziatnikov')],
#              'attract': [(136, 'Sofya Semyonovna')],
#              'avoid': [(334, 'Raskolnikov')],
#              'awaiting': [(153, 'Rodya')],
#              'backed': [(143, 'Darya Frantsovna')],
#              'beat': [(173, 'Razumihin'),
#                       (151, 'Nastasya'),
#                       (157, 'Marfa Petrovna'),
#                       (132, 'Lizaveta')],
#              'beaten': [(278, 'Napoleon')],
#              'beating': [(217, 'Razumihin'), (216, 'Nikolay')],
#              'beg': [(249, 'Sonia'),
#                      (225, 'Lebeziatnikov'),
#                      (247, 'Amalia Ivanovna'),
#                      (246, 'Amalia Ludwigovna')],
#              'began': [(159, 'Pyotr Petrovitch'), (207, 'Zametov')],
#              'begged': [(247, 'Amalia Ivanovna'), (189, 'Karl')],
#              'believe': [(131, 'Raskolnikov'),
#                          (213, 'Porfiry'),
#                          (156, 'Svidrigaïlov'),
#                          (216, 'Nikolay'),
#                          (225, 'Lebeziatnikov'),
#                          (334, 'Raskolnikov')],
#              'believed': [(137, 'Lebeziatnikov')],
#              'betray': [(131, 'Raskolnikov')],
#              'blame': [(138, 'Katerina Ivanovna'),
#                        (247, 'Amalia Ivanovna'),
#                        (295, 'Philip')],
#              'blamed': [(161, 'Raskolnikov'),
#                         (263, 'Brother'),
#                         (306, 'Terebyeva')],
#              'blast': [(182, 'Mitka')],
#              'blow': [(186, 'Tchebarov')],
#              'boring': [(166, 'Mother')],
#              'bound': [(207, 'Zametov'), (163, 'Luzhin')],
#              'brain': [(267, 'Raskolnikov')],
#              'bring': [(249, 'Sonia'), (207, 'Zametov'), (240, 'Papa')],
#              'bringing': [(133, 'Alyona Ivanovna')],
#              'brought': [(138, 'Katerina Ivanovna'),
#                          (216, 'Nikolay'),
#                          (201, 'Zossimov'),
#                          (207, 'Zametov'),
#                          (132, 'Lizaveta'),
#                          (133, 'Alyona Ivanovna'),
#                          (278, 'Napoleon')],
#              'buried': [(157, 'Marfa Petrovna')],
#              'call': [(154, 'Dounia'),
#                       (137, 'Lebeziatnikov'),
#                       (136, 'Sofya Semyonovna'),
#                       (246, 'Amalia Ludwigovna')],
#              'called': [(173, 'Razumihin'), (137, 'Lebeziatnikov')],
#              'calls': [(111, 'Dostoevsky'), (199, 'Pashenka'), (228, 'Man')],
#              'carried': [(139, 'Sonia')],
#              'carry': [(139, 'Sonia')],
#              'catch': [(217, 'Razumihin')],
#              'caught': [(216, 'Nikolay'),
#                         (201, 'Zossimov'),
#                         (247, 'Amalia Ivanovna')],
#              'cheat': [(216, 'Nikolay')],
#              'checked': [(164, 'Avdotya Romanovna')],
#              'circling': [(213, 'Porfiry')],
#              'come': [(300, 'Mary')],
#              'comforts': [(138, 'Katerina Ivanovna')],
#              'compensate': [(138, 'Katerina Ivanovna')],
#              'condemned': [(111, 'Dostoevsky')],
#              'contact': [(352, 'Gutenberg Literary Archive Foundation')],
#              'contradict': [(194, 'Heruvimov')],
#              'convinced': [(334, 'Raskolnikov')],
#              'covered': [(181, 'Koch')],
#              'cried': [(131, 'Raskolnikov'),
#                        (161, 'Raskolnikov'),
#                        (249, 'Sonia'),
#                        (217, 'Razumihin'),
#                        (213, 'Porfiry'),
#                        (154, 'Dounia'),
#                        (164, 'Avdotya Romanovna'),
#                        (173, 'Razumihin'),
#                        (285, 'Svidrigaïlov'),
#                        (163, 'Luzhin'),
#                        (137, 'Lebeziatnikov'),
#                        (176, 'Mikolka')],
#              'crossing': [(161, 'Raskolnikov'), (166, 'Mother')],
#              'crush': [(173, 'Razumihin')],
#              'crushed': [(161, 'Raskolnikov')],
#              'curtsied': [(183, 'Luise Ivanovna')],
#              'cut': [(138, 'Katerina Ivanovna'), (163, 'Luzhin')],
#              'cutting': [(263, 'Brother')],
#              'damned': [(163, 'Luzhin')],
#              'dandling': [(192, 'Pestryakov')],
#              'deceived': [(163, 'Luzhin')],
#              'defending': [(225, 'Lebeziatnikov')],
#              'deserted': [(181, 'Koch')],
#              'deserting': [(181, 'Koch')],
#              'despise': [(136, 'Sofya Semyonovna')],
#              'despising': [(225, 'Lebeziatnikov')],
#              'detained': [(215, 'Dushkin')],
#              'detest': [(163, 'Luzhin')],
#              'developing': [(136, 'Sofya Semyonovna')],
#              'devoured': [(334, 'Raskolnikov')],
#              'dislike': [(285, 'Svidrigaïlov')],
#              'distressed': [(173, 'Razumihin')],
#              'disturb': [(285, 'Svidrigaïlov')],
#              'does': [(285, 'Svidrigaïlov')],
#              'draw': [(207, 'Zametov')],
#              'dressed': [(247, 'Amalia Ivanovna')],
#              'drew': [(131, 'Raskolnikov'), (334, 'Raskolnikov')],
#              'drive': [(213, 'Porfiry'), (173, 'Razumihin')],
#              'drove': [(136, 'Sofya Semyonovna'), (139, 'Sonia')],
#              'drown': [(207, 'Zametov')],
#              'drowned': [(268, 'Madame Resslich')],
#              'duping': [(225, 'Lebeziatnikov')],
#              'educated': [(187, 'Ilya Petrovitch')],
#              'embraced': [(154, 'Dounia')],
#              'encouraged': [(247, 'Amalia Ivanovna')],
#              'enraged': [(225, 'Lebeziatnikov')],
#              'entreating': [(157, 'Marfa Petrovna')],
#              'escape': [(213, 'Porfiry')],
#              'examine': [(213, 'Porfiry')],
#              'excited--“good': [(134, 'God')],
#              'exclaimed': [(161, 'Raskolnikov')],
#              'excuse': [(131, 'Raskolnikov'),
#                         (161, 'Raskolnikov'),
#                         (164, 'Avdotya Romanovna'),
#                         (164, 'Avdotya Romanovna'),
#                         (159, 'Pyotr Petrovitch'),
#                         (163, 'Luzhin'),
# ...
#              'keep': [(164, 'Avdotya Romanovna')],
#              'kept': [(173, 'Razumihin')],
#              'kill': [(156, 'Svidrigaïlov'), (132, 'Lizaveta')],
#              'killed': [(161, 'Raskolnikov'),
#                         (249, 'Sonia'),
#                         (132, 'Lizaveta'),
#                         (191, 'Nikodim Fomitch')],
#              'kissing': [(329, 'Katia')],
#              'know': [(131, 'Raskolnikov'),
#                       (213, 'Porfiry'),
#                       (154, 'Dounia'),
#                       (153, 'Rodya'),
#                       (164, 'Avdotya Romanovna'),
#                       (173, 'Razumihin'),
#                       (285, 'Svidrigaïlov'),
#                       (181, 'Koch'),
#                       (225, 'Lebeziatnikov'),
#                       (132, 'Lizaveta'),
#                       (160, 'Afanasy Ivanovitch'),
#                       (268, 'Madame Resslich'),
#                       (215, 'Dushkin'),
#                       (146, 'Ivan Afanasyvitch')],
#              'known': [(207, 'Zametov')],
#              'knows': [(160, 'Afanasy Ivanovitch')],
#              'laid': [(139, 'Sonia'), (301, 'Jesus')],
#              'leave': [(153, 'Rodya'),
#                        (164, 'Avdotya Romanovna'),
#                        (201, 'Zossimov'),
#                        (225, 'Lebeziatnikov')],
#              'leaving': [(331, 'Parasha')],
#              'led': [(163, 'Luzhin'),
#                      (111, 'Dostoevsky'),
#                      (147, 'Semyon Zaharovitch')],
#              'left': [(131, 'Raskolnikov'),
#                       (217, 'Razumihin'),
#                       (164, 'Avdotya Romanovna'),
#                       (157, 'Marfa Petrovna'),
#                       (295, 'Philip')],
#              'locked': [(152, 'Praskovya Pavlovna')],
#              'looking': [(181, 'Koch')],
#              'lost': [(181, 'Koch')],
#              'love': [(249, 'Sonia'),
#                       (217, 'Razumihin'),
#                       (154, 'Dounia'),
#                       (156, 'Svidrigaïlov'),
#                       (153, 'Rodya'),
#                       (239, 'Polenka'),
#                       (166, 'Mother')],
#              'loved': [(301, 'Jesus'), (166, 'Mother'), (245, 'Lida')],
#              'loves': [(153, 'Rodya'), (166, 'Mother')],
#              'make': [(334, 'Raskolnikov')],
#              'married': [(157, 'Marfa Petrovna'), (307, 'Varents')],
#              'marry': [(153, 'Rodya'), (163, 'Luzhin'), (257, 'Luzhin')],
#              'marrying': [(153, 'Rodya'),
#                           (159, 'Pyotr Petrovitch'),
#                           (163, 'Luzhin')],
#              'means': [(136, 'Sofya Semyonovna')],
#              'meet': [(163, 'Luzhin')],
#              'mentioned': [(267, 'Raskolnikov')],
#              'met': [(216, 'Nikolay'),
#                      (201, 'Zossimov'),
#                      (334, 'Raskolnikov'),
#                      (301, 'Jesus')],
#              'mislead': [(207, 'Zametov')],
#              'missing': [(157, 'Marfa Petrovna'), (157, 'Marfa Petrovna')],
#              'mistrusting': [(181, 'Koch')],
#              'motioned': [(151, 'Nastasya')],
#              'mumbled': [(201, 'Zossimov')],
#              'murdered': [(163, 'Luzhin'),
#                           (132, 'Lizaveta'),
#                           (133, 'Alyona Ivanovna')],
#              'murdering': [(132, 'Lizaveta')],
#              'muttered': [(249, 'Sonia'),
#                           (213, 'Porfiry'),
#                           (164, 'Avdotya Romanovna'),
#                           (285, 'Svidrigaïlov')],
#              'needed': [(138, 'Katerina Ivanovna')],
#              'notice': [(201, 'Zossimov')],
#              'noticed': [(156, 'Svidrigaïlov'),
#                          (173, 'Razumihin'),
#                          (139, 'Sonia')],
#              'obey': [(201, 'Zossimov')],
#              'obliged': [(173, 'Razumihin'), (210, 'Tolstyakov')],
#              'observed': [(161, 'Raskolnikov'),
#                           (154, 'Dounia'),
#                           (173, 'Razumihin'),
#                           (201, 'Zossimov'),
#                           (207, 'Zametov'),
#                           (151, 'Nastasya')],
#              'occupied': [(153, 'Rodya')],
#              'offended': [(154, 'Dounia'), (159, 'Pyotr Petrovitch')],
#              'overcome': [(151, 'Nastasya')],
#              'overtake': [(201, 'Zossimov')],
#              'overwhelmed': [(249, 'Sonia')],
#              'paid': [(139, 'Sonia')],
#              'panting': [(181, 'Koch')],
#              'passed': [(173, 'Razumihin')],
#              'persecuting': [(263, 'Brother')],
#              'perturbed': [(221, 'CHAPTER V This')],
#              'plying': [(151, 'Nastasya')],
#              'praise': [(207, 'Zametov')],
#              'promised': [(159, 'Pyotr Petrovitch'), (247, 'Amalia Ivanovna')],
#              'pronounced': [(159, 'Pyotr Petrovitch')],
#              'protect': [(136, 'Sofya Semyonovna')],
#              'pull': [(239, 'Polenka'),
#                       (234, 'Afrosinya'),
#                       (262, 'Lieutenant Potanchikov')],
#              'pulled': [(181, 'Koch')],
#              'put': [(131, 'Raskolnikov'),
#                      (217, 'Razumihin'),
#                      (247, 'Amalia Ivanovna'),
#                      (239, 'Polenka'),
#                      (240, 'Papa'),
#                      (240, 'Papa')],
#              'putting': [(217, 'Razumihin')],
#              'puzzled': [(285, 'Svidrigaïlov')],
#              'question': [(213, 'Porfiry'), (207, 'Zametov')],
#              'reached': [(139, 'Sonia')],
#              'read': [(295, 'Philip')],
#              'reassure': [(161, 'Raskolnikov')],
#              'reassured': [(153, 'Rodya')],
#              'received': [(111, 'Dostoevsky')],
#              'reckon': [(207, 'Zametov')],
#              'recognised': [(138, 'Katerina Ivanovna'),
#                             (151, 'Nastasya'),
#                             (139, 'Sonia')],
#              'recognising': [(139, 'Sonia')],
#              'reconciled': [(154, 'Dounia'), (153, 'Rodya')],
#              'refuse': [(159, 'Pyotr Petrovitch')],
#              'regard': [(334, 'Raskolnikov')],
#              'regarded': [(225, 'Lebeziatnikov')],
#              'remember': [(216, 'Nikolay'),
#                           (201, 'Zossimov'),
#                           (181, 'Koch'),
#                           (183, 'Luise Ivanovna'),
#                           (262, 'Lieutenant Potanchikov')],
#              'remembered': [(151, 'Nastasya'), (157, 'Marfa Petrovna')],
#              'remembers': [(147, 'Semyon Zaharovitch')],
#              'reminded': [(154, 'Dounia')],
#              'reminding': [(156, 'Svidrigaïlov')],
#              'repeated': [(216, 'Nikolay'), (137, 'Lebeziatnikov')],
#              'repel': [(207, 'Zametov')],
#              'reproached': [(156, 'Svidrigaïlov')],
#              'respect': [(136, 'Sofya Semyonovna'), (257, 'Luzhin')],
#              'respected': [(138, 'Katerina Ivanovna')],
#              'restrain': [(138, 'Katerina Ivanovna'),
#                           (159, 'Pyotr Petrovitch'),
#                           (285, 'Svidrigaïlov'),
#                           (207, 'Zametov'),
#                           (267, 'Raskolnikov')],
#              'retorted': [(151, 'Nastasya')],
#              'reviling': [(139, 'Sonia')],
#              'rig': [(159, 'Pyotr Petrovitch')],
#              'rouse': [(136, 'Sofya Semyonovna')],
#              'said': [(157, 'Marfa Petrovna'),
#                       (334, 'Raskolnikov'),
#                       (263, 'Brother')],
#              'satisfied': [(334, 'Raskolnikov')],
#              'save': [(156, 'Svidrigaïlov'), (234, 'Afrosinya')],
#              'saved': [(156, 'Svidrigaïlov')],
#              'saw': [(131, 'Raskolnikov'),
#                      (154, 'Dounia'),
#                      (156, 'Svidrigaïlov'),
#                      (138, 'Katerina Ivanovna'),
#                      (157, 'Marfa Petrovna'),
#                      (139, 'Sonia'),
#                      (301, 'Jesus'),
#                      (329, 'Katia')],
#              'scanning': [(163, 'Luzhin')],
#              'scolding': [(151, 'Nastasya')],
#              'scrutinised': [(201, 'Zossimov')],
#              'see': [(131, 'Raskolnikov'),
#                      (161, 'Raskolnikov'),
#                      (249, 'Sonia'),
#                      (217, 'Razumihin'),
#                      (213, 'Porfiry'),
#                      (154, 'Dounia'),
#                      (156, 'Svidrigaïlov'),
#                      (153, 'Rodya'),
#                      (164, 'Avdotya Romanovna'),
#                      (138, 'Katerina Ivanovna'),
#                      (173, 'Razumihin'),
#                      (285, 'Svidrigaïlov'),
#                      (216, 'Nikolay'),
#                      (201, 'Zossimov'),
#                      (207, 'Zametov'),
#                      (157, 'Marfa Petrovna'),
#                      (136, 'Sofya Semyonovna'),
#                      (139, 'Sonia'),
#                      (134, 'God'),
#                      (334, 'Raskolnikov')],
#              'seeing': [(153, 'Rodya')],
#              'seen': [(217, 'Razumihin'),
#                       (156, 'Svidrigaïlov'),
#                       (159, 'Pyotr Petrovitch'),
#                       (285, 'Svidrigaïlov'),
#                       (163, 'Luzhin'),
#                       (136, 'Sofya Semyonovna'),
#                       (132, 'Lizaveta'),
#                       (139, 'Sonia'),
#                       (257, 'Luzhin')],
#              'seizing': [(267, 'Raskolnikov')],
#              'sell': [(154, 'Dounia')],
#              'send': [(159, 'Pyotr Petrovitch'), (132, 'Lizaveta')],
#              'sent': [(216, 'Nikolay'),
#                       (137, 'Lebeziatnikov'),
#                       (239, 'Polenka')],
#              'set': [(247, 'Amalia Ivanovna')],
#              'setting': [(163, 'Luzhin')],
#              'settle': [(163, 'Luzhin')],
#              'shaking': [(151, 'Nastasya')],
#              'shouted': [(173, 'Razumihin')],
#              'show': [(157, 'Marfa Petrovna'), (137, 'Lebeziatnikov')],
#              'showed': [(240, 'Papa')],
#              'slapping': [(207, 'Zametov')],
#              'smartened': [(138, 'Katerina Ivanovna')],
#              'spared': [(163, 'Luzhin')],
#              'spending': [(239, 'Polenka')],
#              'squeezed': [(216, 'Nikolay')],
#              'stabbed': [(249, 'Sonia')],
#              'starve': [(199, 'Pashenka')],
#              'stood': [(132, 'Lizaveta')],
#              'stopped': [(181, 'Koch'),
#                          (225, 'Lebeziatnikov'),
#                          (187, 'Ilya Petrovitch')],
#              'strikes': [(159, 'Pyotr Petrovitch')],
#              'struck': [(131, 'Raskolnikov'),
#                         (161, 'Raskolnikov'),
#                         (164, 'Avdotya Romanovna'),
#                         (159, 'Pyotr Petrovitch'),
#                         (207, 'Zametov'),
#                         (137, 'Lebeziatnikov'),
#                         (267, 'Raskolnikov'),
#                         (278, 'Napoleon'),
#                         (339, 'Achilles')],
#              'stuck': [(247, 'Amalia Ivanovna'), (267, 'Raskolnikov')],
#              'take': [(131, 'Raskolnikov'),
#                       (154, 'Dounia'),
#                       (156, 'Svidrigaïlov'),
#                       (216, 'Nikolay'),
#                       (137, 'Lebeziatnikov'),
#                       (139, 'Sonia'),
#                       (160, 'Afanasy Ivanovitch')],
#              'taken': [(161, 'Raskolnikov'),
#                        (216, 'Nikolay'),
#                        (181, 'Koch'),
#                        (157, 'Marfa Petrovna'),
#                        (278, 'Napoleon')],
#              'taking': [(131, 'Raskolnikov')],
#              'taught': [(239, 'Polenka')],
#              'teaching': [(245, 'Lida')],
#              'tease': [(157, 'Marfa Petrovna')],
#              'tell': [(131, 'Raskolnikov'),
#                       (161, 'Raskolnikov'),
#                       (161, 'Raskolnikov'),
#                       (249, 'Sonia'),
#                       (217, 'Razumihin'),
#                       (213, 'Porfiry'),
#                       (213, 'Porfiry'),
#                       (154, 'Dounia'),
#                       (156, 'Svidrigaïlov'),
#                       (156, 'Svidrigaïlov'),
#                       (153, 'Rodya'),
#                       (164, 'Avdotya Romanovna'),
#                       (138, 'Katerina Ivanovna'),
#                       (173, 'Razumihin'),
#                       (285, 'Svidrigaïlov'),
#                       (201, 'Zossimov'),
#                       (207, 'Zametov'),
#                       (151, 'Nastasya'),
#                       (163, 'Luzhin'),
#                       (157, 'Marfa Petrovna'),
#                       (225, 'Lebeziatnikov'),
#                       (136, 'Sofya Semyonovna'),
#                       (239, 'Polenka'),
#                       (199, 'Pashenka'),
#                       (166, 'Mother'),
#                       (183, 'Luise Ivanovna')],
#              'telling': [(156, 'Svidrigaïlov'), (166, 'Mother')],
#              'tempted': [(154, 'Dounia'), (181, 'Koch')],
#              'test': [(136, 'Sofya Semyonovna')],
#              'thank': [(137, 'Lebeziatnikov'),
#                        (134, 'God'),
#                        (134, 'God'),
#                        (152, 'Praskovya Pavlovna'),
#                        (178, 'Father')],
#              'thanked': [(243, 'Prince Schegolskoy')],
#              'thanking': [(137, 'Lebeziatnikov')],
#              'thought': [(131, 'Raskolnikov'), (161, 'Raskolnikov')],
#              'threw': [(239, 'Polenka')],
#              'throw': [(159, 'Pyotr Petrovitch')],
#              'told': [(131, 'Raskolnikov'),
#                       (161, 'Raskolnikov'),
#                       (249, 'Sonia'),
#                       (217, 'Razumihin'),
#                       (213, 'Porfiry'),
#                       (154, 'Dounia'),
#                       (156, 'Svidrigaïlov'),
#                       (164, 'Avdotya Romanovna'),
#                       (173, 'Razumihin'),
#                       (159, 'Pyotr Petrovitch'),
#                       (285, 'Svidrigaïlov'),
#                       (207, 'Zametov'),
#                       (151, 'Nastasya'),
#                       (225, 'Lebeziatnikov'),
#                       (267, 'Raskolnikov'),
#                       (166, 'Mother'),
#                       (194, 'Heruvimov'),
#                       (243, 'Prince Schegolskoy')],
#              'took': [(216, 'Nikolay'), (245, 'Lida'), (189, 'Karl')],
#              'treat': [(187, 'Ilya Petrovitch')],
#              'treated': [(138, 'Katerina Ivanovna'),
#                          (136, 'Sofya Semyonovna'),
#                          (329, 'Katia')],
#              'treating': [(247, 'Amalia Ivanovna')],
#              'trouble': [(285, 'Svidrigaïlov')],
#              'trust': [(217, 'Razumihin')],
#              'turn': [(147, 'Semyon Zaharovitch')],
#              'understand': [(217, 'Razumihin')],
#              'untied': [(126, 'Grigoryev')],
#              'used': [(138, 'Katerina Ivanovna')],
#              'visit': [(285, 'Svidrigaïlov')],
#              'waked': [(181, 'Koch')],
#              'want': [(157, 'Marfa Petrovna')],
#              'wanted': [(216, 'Nikolay'),
#                         (151, 'Nastasya'),
#                         (225, 'Lebeziatnikov')],
#              'warn': [(249, 'Sonia'), (156, 'Svidrigaïlov')],
#              'watched': [(156, 'Svidrigaïlov'), (137, 'Lebeziatnikov')],
#              'watching': [(161, 'Raskolnikov')],
#              'waved': [(138, 'Katerina Ivanovna')],
#              'weakened': [(181, 'Koch')],
#              'wear': [(132, 'Lizaveta')],
#              'weighed': [(111, 'Dostoevsky')],
#              'went': [(147, 'Semyon Zaharovitch')],
#              'whispered': [(249, 'Sonia'), (178, 'Father')],
#              'woke': [(181, 'Koch')],
#              'worried': [(249, 'Sonia'), (247, 'Amalia Ivanovna')],
#              'worry': [(161, 'Raskolnikov')],
#              'wound': [(138, 'Katerina Ivanovna')],
#              'wronged': [(136, 'Sofya Semyonovna')],
#              'wrote': [(153, 'Rodya')]}}

# %%
pprint(list(verb_data["agent"].keys())[:40], compact=True)
# Out:
# ['said', 'know', 'felt', 'went', 'had', 'thought', 'looked', 'come', 'want',
#  'have', 'believe', 'walked', 'began', 'heard', 'think', 'tell', 'made',
#  'stood', 'turned', 'asked', 'understand', 'saw', 'cried', 'see', 'answered',
#  'go', 'seen', 'gave', 'sat', 'knew', 'came', 'whispered', 'got', 'told',
#  'talking', 'took', 'give', 'let', 'say', 'has']

# %%
pprint(list(verb_data["patient"].keys())[:40], compact=True)
# Out:
# ['tell', 'see', 'told', 'asked', 'cried', 'struck', 'left', 'arrest', 'take',
#  'thought', 'excuse', 'betray', 'addressing', 'saw', 'put', 'taking', 'drew',
#  'know', 'believe', 'assure', 'taken', 'worry', 'killed', 'forgive', 'blamed',
#  'exclaimed', 'added', 'crossing', 'observed', 'crushed', 'reassure',
#  'watching', 'whispered', 'love', 'beg', 'followed', 'accompanied', 'find',
#  'ask', 'worried']

# %%
verb_data["agent"]["died"]
# Out:
# [(157, 'Marfa Petrovna'), (111, 'Dostoevsky')]

# %%
verb_data["agent"]["lies"]
# Out:
# [(215, 'Dushkin')]

# %%
verb_data["agent"]["kill"]
# Out:
# [(216, 'Nikolay'), (176, 'Mikolka'), (189, 'Karl')]

# %%
verb_data["agent"]["thrashed"]
# Out:
# [(176, 'Mikolka')]

# %%
verb_data["agent"]["love"]
# Out:
# [(239, 'Polenka'), (166, 'Mother')]

# %%
verb_data["agent"]["loves"]
# Out:
# [(154, 'Dounia'), (199, 'Pashenka')]

# %%
verb_data["patient"]["tempted"]
# Out:
# [(154, 'Dounia'), (181, 'Koch')]

# %%
verb_data["patient"]["blow"]
# Out:
# [(186, 'Tchebarov')]

# %%
verb_data["patient"]["betray"]
# Out:
# [(131, 'Raskolnikov')]

# %%
verb_data["patient"]["stabbed"]
# Out:
# [(249, 'Sonia')]

# %%
verb_data["patient"]["struck"]
# Out:
# [(131, 'Raskolnikov'),
#  (161, 'Raskolnikov'),
#  (164, 'Avdotya Romanovna'),
#  (159, 'Pyotr Petrovitch'),
#  (207, 'Zametov'),
#  (137, 'Lebeziatnikov'),
#  (267, 'Raskolnikov'),
#  (278, 'Napoleon'),
#  (339, 'Achilles')]

# %% [markdown]
# ## event analysis
#
# code source: https://booknlp.pythonhumanities.com/05_events.html#

# %%
events = tokens[~tokens['event'].isnull()]
events
# Out:
#         paragraph_ID  sentence_ID  token_ID_within_sentence  \
# 0                  0            0                         0
# 1                  0            0                         1
# 2                  0            0                         2
# 3                  0            0                         3
# 4                  0            0                         4
# ...              ...          ...                       ...
# 130145          3976        13448                         3
# 130146          3976        13448                         4
# 130147          3976        13448                         5
# 130148          3976        13448                         6
# 130149          3976        13448                         7
#
#         token_ID_within_document         word       lemma  byte_onset  \
# 0                              0         ﻿The        ﻿the           0
# 1                              1      Project     Project           5
# 2                              2    Gutenberg   Gutenberg          13
# 3                              3        eBook       eBook          23
# 4                              4           of          of          29
# ...                          ...          ...         ...         ...
# 130145                    252853          her         her     1135119
# 130146                    252854  aspirations  aspiration     1135123
# 130147                    252855           at          at     1135135
# 130148                    252856        least       least     1135138
# 130149                    252857         ....        ....     1135143
#
#         byte_offset POS_tag fine_POS_tag dependency_relation  \
# 0                 4    PRON           DT                nmod
# 1                12   PROPN          NNP            compound
# 2                22   PROPN          NNP            compound
# 3                28   PROPN          NNP               nsubj
# 4                31     ADP           IN                prep
# ...             ...     ...          ...                 ...
# 130145      1135122    PRON         PRP$                poss
# 130146      1135134    NOUN          NNS            npadvmod
# 130147      1135137     ADP           IN                prep
# 130148      1135143     ADJ          JJS                pobj
# 130149      1135147   PUNCT            .               punct
#
#         syntactic_head_ID event
# 0                       3     O
# 1                       3     O
# 2                       3     O
# 3                      14     O
# 4                       3     O
# ...                   ...   ...
# 130145             252854     O
# 130146             252864     O
# 130147             252854     O
# 130148             252855     O
# 130149             252854     O
#
# [130150 rows x 13 columns]

# %%
real_events = events.loc[events["event"] == "EVENT"]
real_events
# Out:
#         paragraph_ID  sentence_ID  token_ID_within_sentence  \
# 266               16           12                        12
# 287               17           14                         3
# 336               17           17                         4
# 358               18           18                        20
# 368               18           19                         2
# ...              ...          ...                       ...
# 129186          3946        13251                        36
# 129310          3947        13254                         5
# 129909          3952        13288                        11
# 129912          3952        13288                        14
# 129939          3953        13289                         7
#
#         token_ID_within_document         word        lemma  byte_onset  \
# 266                          266  examination  examination        1423
# 287                          291    published      publish        1548
# 336                          340     arrested       arrest        1813
# 358                          362          met         meet        1940
# 368                          372      accused       accuse        1990
# ...                          ...          ...          ...         ...
# 129186                    249121        wrote        write     1117304
# 129310                    249245        wrote        write     1117918
# 129909                    249847      thought        think     1120696
# 129912                    249850   criticised    criticise     1120713
# 129939                    249882        asked          ask     1120861
#
#         byte_offset POS_tag fine_POS_tag dependency_relation  \
# 266            1434    NOUN           NN                pobj
# 287            1557    VERB          VBN                ROOT
# 336            1821    VERB          VBN                ROOT
# 358            1943    VERB          VBD               relcl
# 368            1997    VERB          VBN                ROOT
# ...             ...     ...          ...                 ...
# 129186      1117309    VERB          VBD                ROOT
# 129310      1117923    VERB          VBD                ROOT
# 129909      1120703    VERB          VBD                ROOT
# 129912      1120723    VERB          VBD                conj
# 129939      1120866    VERB          VBD                ROOT
#
#         syntactic_head_ID  event
# 266                   263  EVENT
# 287                   291  EVENT
# 336                   340  EVENT
# 358                   360  EVENT
# 368                   372  EVENT
# ...                   ...    ...
# 129186             249121  EVENT
# 129310             249245  EVENT
# 129909             249847  EVENT
# 129912             249847  EVENT
# 129939             249882  EVENT
#
# [5992 rows x 13 columns]

# %%
def get_event_sentences(df):
    real_events = df.loc[df["event"] == "EVENT"]
    sentences = real_events.sentence_ID.tolist()
    event_words = real_events.word.tolist()
    event_lemmas = real_events.lemma.tolist()
    final_sentences = []
    for i, sentence in enumerate(sentences):
        result = df[df["sentence_ID"] == int(sentence)]
        words = result.word.tolist()
        resentence = " ".join(words)
        final_sentences.append(
            {
                "event_word": event_words[i],
                "event_lemma": event_lemmas[i],
                "sentence": resentence,
            }
        )
    return pd.DataFrame(final_sentences)

# %%
events = get_event_sentences(tokens)
events
# Out:
#        event_word  event_lemma  \
# 0     examination  examination
# 1       published      publish
# 2        arrested       arrest
# 3             met         meet
# 4         accused       accuse
# ...           ...          ...
# 5987        wrote        write
# 5988        wrote        write
# 5989      thought        think
# 5990   criticised    criticise
# 5991        asked          ask
#
#                                                sentence
# 0     Though always sickly and delicate Dostoevsky c...
# 1     This story was published by the poet Nekrassov...
# 2                             In 1849 he was arrested .
# 3     Though neither by temperament nor conviction a...
# 4                                   He was accused of “
# ...                                                 ...
# 5987  On working days she would go to see him at wor...
# 5988  In the last letter Sonia wrote that he had bee...
# 5989  But now in prison , _ in freedom _ , he though...
# 5990  But now in prison , _ in freedom _ , he though...
# 5991                             “ he asked himself , “
#
# [5992 rows x 3 columns]

# %%
pprint(list(events["event_word"].unique()), compact=True)
# Out:
# ['examination', 'published', 'arrested', 'met', 'accused', 'condemned', 'taken',
#  'says', 'commuted', 'mad', 'untied', 'arrest', 'attacks', 'fits', 'allowed',
#  'started', 'speech', 'unveiling', 'demonstrations', 'died', 'followed', 'came',
#  'lodged', 'walked', 'feeling', 'given', 'coming', 'aware', 'fears', 'thought',
#  'smile', 'heat', 'completed', 'expression', 'confessed', 'dragged', 'shouted',
#  'drove', 'bawling', 'pointing', 'stopped', 'clutched', 'overtaken', 'muttered',
#  'counted', 'tantalising', 'look', 'monologues', 'jeered', 'regard', 'dream',
#  'excitement', 'tremor', 'went', 'going', 'glad', 'slipped', 'asking',
#  'reached', 'progress', 'barred', 'moving', 'rang', 'tinkle', 'overstrained',
#  'opened', 'eyed', 'glittering', 'seeing', 'bolder', 'stepped', 'facing',
#  'looking', 'flapping', 'coughed', 'groaned', 'gleam', 'haste', 'mutter', 'bow',
#  'remembering', 'said', 'inquiring', 'continued', 'disconcerted', 'surprised',
#  'mistrust', 'paused', 'letting', 'pass', 'lighted', 'setting', 'flashed',
#  'glance', 'scanned', 'trying', 'burning', 'drew', 'cried', 'say', 'lent',
#  'asked', 'admonishes', 'studying', 'beating', 'come', 'beat', 'ask', 'set',
#  'began', 'waiting', 'laughter', 'declared', 'hearing', 'sniggering', 'sold',
#  'coughing', 'spitting', 'read', 'addressed', 'leaving', 'danced', 'dance',
#  'presented', 'showed', 'took', 'blows', 'married', 'ran', 'gave', 'trouble',
#  'paid', 'speaks', 'tears', 'throws', 'left', 'death', 'thrown', 'honoured',
#  'offered', 'Weeping', 'sobbing', 'wringing', 'lost', 'obtained', 'end',
#  'address', 'stamping', 'reviling', 'walking', 'heard', 'speaking', 'jeer',
#  'crying', 'saw', 'get', 'put', 'go', 'laid', 'picked', 'lay', 'kissing',
#  'asleep', 'drunk', 'sounds', 'voice', 'singing', 'noise', 'talkative',
#  'recollection', 'reflected', 'listened', 'broke', 'tried', 'twitch',
#  'controlled', 'bewildered', 'sensation', 'vexed', 'feel', 'passed', 'dreams',
#  'stole', 'forgotten', 'exchanged', 'bought', 'looked', 'drinking', 'sought',
#  'tasted', 'wanting', 'meant', 'leaned', 'overcome', 'dismay', 'fury', 'seized',
#  'seconded', 'efforts', 'crawling', 'called', 'shaken', 'striking', 'woke',
#  'cry', 'losing', 'trembling', 'screaming', 'rushed', 'shaking', 'screamed',
#  'pointed', 'hastening', 'peering', 'laughing', 'thrust', 'diverted', 'outcry',
#  'pushing', 'ordering', 'abuse', 'changed', 'reflecting', 'dismissed', 'wave',
#  'laughed', 'brought', 'begun', 'upon', 'sat', 'chatting', 'scowled',
#  'grinding', 'added', 'answered', 'pause', 'amused', 'quivering', 'ill',
#  'articulate', 'mentioned', 'agreed', 'doubts', 'thinking', 'settled', 'press',
#  'told', 'tell', 'improved', 'calculated', 'see', 'agreement', 'embrace',
#  'pray', 'kisses', 'apologise', 'observes', 'bitterness', 'intense', 'pursuing',
#  'ideas', 'understood', 'writes', 'question', 'start', 'felt', 'menacing',
#  'hammering', 'searching', 'wanted', 'adventure', 'absorbed', 'attention',
#  'Looking', 'noticed', 'crossed', 'sight', 'riveted', 'intently', 'desire',
#  'waving', 'flung', 'stumbling', 'staggering', 'overtook', 'reaching',
#  'dropped', 'let', 'sink', 'closed', 'lifting', 'found', 'biding', 'longing',
#  'clenching', 'spluttering', 'scowling', 'astonishment', 'raised', 'noticing',
#  'catching', 'addressing', 'taking', 'turned', 'bent', 'examine', 'worked',
#  'deceived', 'sank', 'carried', 'remember', 'meaning', 'preparing', 'flog',
#  'clambered', 'jokes', 'got', 'hauled', 'cracking', 'getting', 'tugged',
#  'struggled', 'gasping', 'shrinking', 'showered', 'redoubled', 'rage',
#  'thrashed', 'tore', 'tugging', 'falling', 'roar', 'covered', 'roused',
#  'shower', 'kicking', 'smiling', 'snatched', 'joined', 'song', 'jingling',
#  'whistling', 'whipped', 'choking', 'streaming', 'cut', 'Wringing', 'gasp',
#  'threw', 'hold', 'effort', 'brandished', 'swinging', 'blow', 'sound', 'thud',
#  'voices', 'swung', 'fell', 'lurched', 'attacking', 'stooped', 'dealt',
#  'staggered', 'leapt', 'dying', 'stretched', 'breath', 'brandishing', 'stood',
#  'shouting', 'made', 'bleeding', 'kissed', 'jumped', 'flew', 'frenzy',
#  'running', 'sobbed', 'words', 'shrieks', 'panting', 'choked', 'waked',
#  'soaked', 'perspiration', 'sitting', 'breaths', 'broken', 'confusion',
#  'rested', 'amazement', 'phenomenon', 'assure', 'joking', 'bit', 'talking',
#  'speechifying', 'arguing', 'struck', 'run', 'cursing', 'fumbling',
#  'conclusions', 'decided', 'conclusion', 'preparation', 'calculations',
#  'glanced', 'hanging', 'Seeing', 'stared', 'passing', 'overwhelmed',
#  'hesitating', 'revolting', 'shining', 'caught', 'approached', 'dashed',
#  'pulled', 'grin', 'curse', 'Glancing', 'considering', 'conviction',
#  'interested', 'walks', 'reality', 'dismiss', 'driven', 'screening', 'drive',
#  'flash', 'hear', 'quarrelling', 'pressing', 'ascending', 'listening', 'torn',
#  'gone', 'floated', 'silence', 'wondered', 'throbbed', 'ringing', 'touch',
#  'rustle', 'moved', 'Recalling', 'unfastened', 'mistake', 'Fearing', 'hoping',
#  'advanced', 'shook', 'held', 'fancied', 'recovered', 'restored',
#  'articulating', 'failing', 'answer', 'sounded', 'scanning', 'weighing',
#  'Trying', 'untie', 'turning', 'unbuttoned', 'freed', 'holding', 'numb',
#  'wooden', 'afraid', 'giddiness', 'returned', 'fastened', 'raising', 'gushed',
#  'fall', 'visit', 'remembered', 'fit', 'shudder', 'tempted', 'smiled', 'idea',
#  'occurred', 'Leaving', 'lifted', 'Bending', 'examining', 'smearing',
#  'mistakes', 'realised', 'fitted', 'unlocked', 'wipe', 'turn', 'filling',
#  'steps', 'moan', 'squatting', 'gazing', 'backing', 'staring', 'twitched',
#  'scared', 'snatching', 'mastery', 'murder', 'longed', 'forgot', 'bethought',
#  'washing', 'washed', 'rubbing', 'wiped', 'hung', 'wetted', 'rubbed', 'shock',
#  'terror', 'gazed', 'waited', 'rung', 'seen', 'scolding', 'separated',
#  'humming', 'tune', 'step', 'footsteps', 'suspect', 'mounting', 'breathing',
#  'Coming', 'succeeded', 'slipping', 'closing', 'fixed', 'helped', 'crouched',
#  'divided', 'panted', 'squeezing', 'tinkled', 'speak', 'bawled', 'enraged',
#  'approaching', 'pulling', 'astonished', 'touched', 'touching', 'puffing',
#  'ready', 'knocking', 'restless', 'deserting', 'hurrying', 'thumping', 'shout',
#  'shriek', 'distinguished', 'painted', 'whisked', 'hidden', 'finding', 'pace',
#  'weakened', 'conscious', 'alarmed', 'recollected', 'putting', 'covering',
#  'forgetfulness', 'dazed', 'cries', 'leaped', 'chill', 'fever', 'sleep',
#  'shivering', 'chattered', 'wondering', 'fallen', 'mistrusting', 'search',
#  'clinging', 'fling', 'stuffing', 'shuddered', 'horror', 'whispered',
#  'drowsiness', 'delirium', 'consciousness', 'pounced', 'repeated', 'torture',
#  'clouded', 'sigh', 'relief', 'poked', 'gathered', 'haunted', 'impulse',
#  'banging', 'pain', 'retorted', 'rose', 'unlatched', 'announced', 'observed',
#  'waking', 'grasped', 'giggle', 'reading', 'summons', 'bewilderment',
#  'flinging', 'dressing', 'loathing', 'shuddering', 'despair', 'swam', 'ached',
#  'mused', 'summoned', 'declaration', 'demanded', 'complaint', 'summon',
#  'warned', 'telling', 'playing', 'hitting', 'hit', 'slaps', 'squealing', 'pay',
#  'scandal', 'eaten', 'aroused', 'fuming', 'protest', 'agree', 'promised',
#  'promise', 'crossing', 'saying', 'signing', 'buried', 'fawned', 'worrying',
#  'fretting', 'encourage', 'proves', 'translating', 'pays', 'marked', 'warrant',
#  'trudging', 'give', 'examined', 'feeding', 'talked', 'request', 'sent',
#  'received', 'decamped', 'angry', 'resolved', 'inquiries', 'acquaintance',
#  'fright', 'hid', 'planned', 'cherishing', 'assured', 'lie', 'turns', 'demand',
#  'insisted', 'presenting', 'chatter', 'cross', 'eager', 'fumbled', 'rummaging',
#  'gulped', 'quenching', 'shiver', 'thoughts', 'disconnected', 'nestled',
#  'wrapped', 'replaced', 'sighed', 'uncertain', 'pondered', 'untying', 'fitting',
#  'offended', 'exhibited', 'waved', 'resistance', 'frowning', 'watching',
#  'watched', 'blurted', 'murmured', 'interrupted', 'silent', 'bringing',
#  'leaning', 'exclaiming', 'stopping', 'affectation', 'deliberation',
#  'scrutinised', 'rising', 'shifting', 'Reflecting', 'softened', 'emphasising',
#  'movement', 'checked', 'mumbled', 'nodding', 'yawn', 'opening', 'arouse',
#  'wonder', 'suspicion', 'alarm', 'articulated', 'pronounced', 'reply',
#  'faltered', 'chosen', 'squeezed', 'Reaching', 'yawned', 'cheerful',
#  'introduced', 'cleared', 'shrugged', 'vexation', 'treated', 'hardened',
#  'breaking', 'replied', 'hastened', 'interpose', 'glancing', 'affronted',
#  'concluded', 'conversation', 'interposed', 'twitching', 'delight', 'insulting',
#  'fixing', 'pale', 'signs', 'insult', 'lingered', 'latched', 'undid', 'tied',
#  'fear', 'calm', 'movements', 'hoped', 'dressed', 'change', 'blowing', 'drank',
#  'energy', 'gleamed', 'walk', 'accompanying', 'sang', 'note', 'startled',
#  'christened', 'accident', 'combustion', 'fire', 'winked', 'talk', 'scuffling',
#  'declare', 'depose', 'fainted', 'trembled', 'hurry', 'crash', 'counting',
#  'finished', 'saved', 'gripped', 'seek', 'parting', 'weaker', 'flush',
#  'gathering', 'flashing', 'darkening', 'swooning', 'parted', 'swallowed',
#  'drowning', 'current', 'inflated', 'crowded', 'sneezing', 'wiping', 'wailed',
#  'disgusted', 'depression', 'apathy', 'whisper', 'prompting', 'working',
#  'perplexed', 'find', 'hesitation', 'mounted', 'papering', 'annoyed', 'rolling',
#  'folded', 'satisfaction', 'jerked', 'driving', 'worse', '...', 'ball',
#  'blessing', 'thanked', 'expressions', 'worn', 'Put', 'beg', 'laugh', 'warn',
#  'robbed', 'drying', 'spoke', 'sending', 'exclamations', 'discussion',
#  'delighted', 'affected', 'brightened', 'thrashing', 'fainting', 'smell',
#  'frightened', 'convulsions', 'convinced', 'want', 'seizing', 'dislocated',
#  'bend', 'consolations', 'revealed', 'emotion', 'gesture', 'wept', 'quarrel',
#  'reporting', 'perplexity', 'suspense', 'swear', 'beseech', 'bring', 'fetch',
#  'pour', 'argument', 'entreat', 'homage', 'forget', 'fetching', 'strum',
#  'perspired', 'admitting', 'nonsense', 'described', 'fetched', 'locked', 'up',
#  'astounded', 'killed', 'marriage', 'rejoiced', 'announcing', 'decision',
#  'inform', 'meeting', 'venture', 'add', 'affront', 'explanation', 'wish',
#  'anticipation', 'meet', 'write', 'assumption', 'leave', 'confirmed', 'belief',
#  'testimony', 'funeral', 'expressing', 'refusing', 'ordered', 'dozed',
#  'dreamed', 'bruised', 'referring', 'realise', 'exaggerated', 'rushing',
#  'delayed', 'wandering', 'chanced', 'observation', 'spattered', 'helping',
#  'carry', 'wrote', 'die', 'stroke', 'perceptible', 'anguish', 'clutching',
#  'bows', 'nodded', 'protested', 'blushing', 'glances', 'dreamy', 'biting',
#  'flushed', 'anxiety', 'handing', 'embarrassed', 'animation', 'resolution',
#  'awaiting', 'surprise', 'confused', 'protesting', 'declaring', 'sorry',
#  'retreat', 'pang', 'stop', 'entrance', 'shown', 'motioned', 'falteringly',
#  'stammered', 'ceased', 'glowed', 'screwed', 'embarrassment', 'keeping',
#  'bowed', 'flutter', 'following', 'curtsy', 'discomfort', 'brightness',
#  'introducing', 'written', 'pawned', 'quaking', 'lodge', 'altered',
#  'mentioning', 'apologising', 'flies', 'wriggling', 'think', 'proved',
#  'begging', 'sniffed', 'informed', 'troubling', 'prize', 'confess', 'expecting',
#  'unconscious', 'delirious', 'sick', 'sensible', 'disturbing', 'wink',
#  'foresaw', 'questions', 'persuaded', 'congratulate', 'analysed', 'regret',
#  'suggested', 'suggestion', 'admit', 'hinted', 'maintain', 'acknowledge',
#  'take', 'painting', 'carrying', 'muddled', 'condescended', 'reckoning',
#  'relish', 'sprang', 'jest', 'starving', 'reason', 'calling', 'aimed',
#  'proposed', 'pretending', 'cherish', 'hope', 'arrived', 'persecuted',
#  'anticipating', 'assume', 'proposing', 'show', 'repeat', 'bathing', 'wrung',
#  'bored', 'act', 'action', 'fancy', 'lounging', 'deteriorated', 'prison',
#  'bargained', 'united', 'bore', 'invited', 'journey', 'comes', 'out', 'tired',
#  'dinner', 'smoking', 'burial', 'defending', 'interrupting', 'arriving',
#  'quarrelled', 'learned', 'offer', 'fancying', 'persecuting', 'attentions',
#  'begged', 'upset', 'cursed', 'pleasure', 'departure', 'discovering', 'hushed',
#  'observe', 'grudged', 'hanged', 'perceive', 'proposition', 'disregarded',
#  'insistance', 'intend', 'insulted', 'misrepresenting', 'expressed', 'accusing',
#  'relied', 'enlarged', 'impression', 'alluded', 'sit', 'appeal', 'tone',
#  'remark', 'bound', 'deny', 'led', 'delivered', 'offers', 'refused', 'planning',
#  'scuttling', 'knelt', 'weeping', 'burst', 'wretched', 'reminded', 'admired',
#  'grieved', 'sad', 'making', 'service', 'controlling', 'troubled', 'groaning',
#  'cometh', 'thank', 'spoken', 'abandoned', 'chose', 'receiving', 'tickled',
#  'bold', 'reassured', 'surrendered', 'lied', 'asks', 'dined', 'throw', 'rush',
#  'tells', 'imposed', 'dejection', 'imagining', 'acquitted', 'learnt', 'invite',
#  'Prompting', 'mocking', 'orders', 'sinned', 'wronged', 'worried', 'skipping',
#  'punching', 'questioning', 'scolded', 'rid', 'blunder', 'preparations',
#  'pushed', 'blamed', 'rejoice', 'developing', 'debate', 'explaining',
#  'expounding', 'referred', 'ascertain', 'feels', 'instructions', 'alluding',
#  'forgive', 'clasped', 'pierced', 'call', 'noted', 'return', 'count', 'entered',
#  'statement', 'describe', 'handed', 'instalment', 'accompanied', 'intending',
#  'disappeared', 'allude', 'accusation', 'present', 'donation', 'commiserating',
#  'witness', 'oath', 'raving', 'kept', 'thanking', 'wants', 'engaged',
#  'insinuating', 'Irritated', 'rude', 'rupture', 'unmasked', 'advise', 'eating',
#  'triumph', 'embracing', 'murdered', 'guessed', 'clasping', 'insistence',
#  'agony', 'wail', 'jumping', 'shine', 'amazed', 'ecstasy', 'supplication',
#  'pondering', 'knocked', 'appeared', 'perturbed', 'hurried', 'fading',
#  'wandered', 'oppress', 'foretaste', 'irritation', 'coaxed', 'appealed',
#  'curious', 'frying', 'rapping', 'clapping', 'sing', 'cough', 'shed', 'furious',
#  'hiding', 'beseeching', 'flow', 'forcing', 'effect', 'pranks', 'wailing',
#  'stumbled', 'bending', 'pressed', 'stained', 'implored', 'plan', 'adopted',
#  'flowing', 'appearance', 'regained', 'supporting', 'suffering', 'recognised',
#  'rattle', 'ejaculated', 'excited', 'shrieking', 'scream', 'regaining',
#  'unconsciousness', 'skipped', 'withdrew', 'phrases', 'believed', 'uneasiness',
#  'Walking', 'arrangement', 'dropping', 'kneeling', 'prayed', 'blessed',
#  'interpreted', 'solitary', 'reduced', 'panic', 'ate', 'warmth', 'throbbing',
#  'descended', 'realising', 'renewed', 'struggle', 'produced', 'tickling', 'owe',
#  'interview', 'explain', 'misunderstanding', 'attracted', 'rumours', 'pitch',
#  'happened', 'reproducing', 'mistiness', 'vibrating', 'mist', 'here',
#  'searched', 'discussing', 'arranged', 'bowled', 'failed', 'agitation',
#  'influencing', 'recantation', 'stooping', 'tormented', 'owning', 'hovering',
#  'exhausted', 'boom', 'aback', 'scrutinising', 'pretended', 'click', 'chorus',
#  'sung', 'rhymes', 'poured', 'trailed', 'impatience', 'persisted', 'parried',
#  'oppressed', 'irritated', 'mockery', 'restrained', 'sipped', 'wetting',
#  'preoccupied', 'sneering', 'suspicious', 'satisfied', 'judgment', 'signalling',
#  'Unlocking', 'laying', 'gasped', 'sprinkled', 'glowing', 'rave', 'cocked',
#  'frantic', 'measuring', 'kindle', 'shot', 'bullet', 'grazed', 'still',
#  'stream', 'lowered', 'weight', 'deliverance', 'gaze', 'smeared', 'drawn',
#  'entertained', 'fight', 'missed', 'clap', 'thunder', 'rain', 'flashes',
#  'lightning', 'Drenched', 'giving', 'tea', 'soaking', 'prepared', 'blushed',
#  'admitted', 'perturbation', 'surmise', 'wheeled', 'wedding', 'patted',
#  'inquiry', 'anger', 'concluding', 'whispering', 'roaring', 'wind', 'cold',
#  'disillusioned', 'murmur', 'upbraiding', 'shaded', 'peeped', 'smiting',
#  'reproached', 'returning', 'feverish', 'wrapping', 'burnt', 'scratching',
#  'reverie', 'disliked', 'blew', 'recalled', 'recommended', 'rousing', 'ground',
#  'image', 'shooting', 'dozing', 'disinclined', 'Shaking', 'zigzags', 'darted',
#  'leap', 'dart', 'howling', 'draught', 'craving', 'dwelling', 'air',
#  'chirruping', 'drowned', 'destroyed', 'crushed', 'appalled', 'smirched',
#  'howled', 'lashed', 'stung', 'drops', 'resounded', 'ticking', 'shut',
#  'animated', 'guess', 'way', 'undressing', 'undressed', 'musing', 'annoyance',
#  'sleeping', 'warm', 'quivered', 'shattered', 'overslept', 'Feeling', 'Reading',
#  'pursuit', 'picturing', 'bigger', 'conflict', 'speechless', 'faltering', 'joy',
#  'frowned', 'embraced', 'minute', 'regretting', 'Going', 'vision', 'plunged',
#  'uttered', 'promises', 'ashamed', 'dark', 'comfort', 'confession', 'impatient',
#  'tortured', 'sure', 'sign', 'stirred', 'doubt', 'dawned', 'chanted',
#  'overwhelming', 'remarks', 'glimpse', 'knew', 'mount', 'collect', 'imagined',
#  'settling', 'seating', 'dining', 'listlessness', 'stifling', 'reeled',
#  'barking', 'stricken', 'grinned', 'crime', 'explained', 'ended', 'indicating',
#  'deduction', 'discovered', 'rescued', 'investigated', 'derangement', 'hinting',
#  'answers', 'gloomy', 'mood', 'evident', 'overheard', 'sentenced', 'separation',
#  'swore', 'lectures', 'melancholy', 'anxious', 'injured', 'rescuing', 'prepare',
#  'fuss', 'visits', 'criticised']

# %%
pprint(events[events["event_word"] == "confess"]["sentence"].values)
# Out:
# array(['He knows , ” Forgive my troubling you about such trifles , ” the things are only worth five roubles , but I prize them particularly for the sake of those from whom they came to me , and I must confess that I was alarmed when I heard ... ” That ’s why you were so much struck when I mentioned to Zossimov that Porfiry was inquiring for everyone who had pledges ! ”',
#        'How did he strike you ? ” I must confess I do n’t quite understand him .',
#        'And although I can not , I confess , in principle sympathise with private charity , for it not only fails to eradicate the evil but even promotes it , yet I must admit that I saw your action with pleasure -- yes , yes , I like it . ” That ’s all nonsense , ”',
#        'We ’ll speak of children later , but now as to the question of honour , I confess that ’s my weak point .',
#        'To the question what led him to confess , he answered that it was his heartfelt repentance .'],
#       dtype=object)
